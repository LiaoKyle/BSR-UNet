# %%
import os
import glob
import h5py
import random
import numpy as np
from tqdm import tqdm
from astropy.io import fits
import matplotlib.pyplot as plt
from scipy.signal import fftconvolve
from pathlib import Path
from astropy.visualization import ZScaleInterval
from PIL import Image

# %%
new_path = r'C:\Users\liaok\OneDrive\Desktop\毕设\data'

# 检查路径是否存在
if os.path.exists(new_path):
    os.chdir(new_path)
    print(f"工作目录已切换到：{new_path}")
# Out:
# 工作目录已切换到：C:\Users\liaok\OneDrive\Desktop\毕设\data

# %% [markdown]
# ### 导入数据（ori.png）

# %%
# 创建输出目录（修改为data_ori_png）
output_dir = 'data_ori_png'
os.makedirs(output_dir, exist_ok=True)

# 打开HDF5文件（网页6、网页7的HDF5处理方案）
with h5py.File('Galaxy10_DECals.h5', 'r') as file:
    images = file['images']

    # 随机选择2500个索引
    random_indices = random.sample(range(len(images)), 2500)

    # 处理流程优化（网页2、网页4的最佳实践）
    for idx in tqdm(random_indices, desc='处理进度', unit='张', colour='green'):
        image_data = images[idx]

        # 维度调整（原始代码逻辑保留）
        if image_data.shape == (256, 3, 256):
            image_data = np.transpose(image_data, (0, 2, 1))  # (256,256,3)

        # 转换为PIL图像对象（网页1、网页4推荐方案）
        pil_img = Image.fromarray(image_data.astype(np.uint8))

        # 高质量缩放（网页4建议使用LANCZOS插值）
        resized_img = pil_img.resize((512, 512), resample=Image.Resampling.LANCZOS)

        # 保存为PNG（网页2、网页4的标准保存方法）
        resized_img.save(os.path.join(output_dir, f'galaxy_image_{idx}_512.png'))
# Out:
# 处理进度: 100%|██████████| 2500/2500 [23:01<00:00,  1.81张/s]

# %% [markdown]
# ### ori.png->ori.fit

# %%
src_dir = "data_ori_png"
dst_dir = "data_ori_fit"
os.makedirs(dst_dir, exist_ok=True)

for filename in os.listdir(src_dir):
    if filename.endswith(".png") and "_512" in filename:
        new_name = filename.replace("_512", "")[:-4] + ".fit"
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_dir, new_name)

        try:
            # 关键处理步骤
            with Image.open(src_path) as img:
                # 转换为单通道灰度图（确保二维）
                gray_img = img.convert('L')
                img_data = np.array(gray_img)

            # 验证数据维度
            if len(img_data.shape) != 2:
                raise ValueError(f"数据维度异常：{img_data.shape}，应确保输出二维数组")

            # 创建FITS结构
            hdu = fits.PrimaryHDU(img_data)
            hdu.writeto(dst_path, overwrite=True)
            print(f"成功转换: {filename} -> {new_name} (维度：{img_data.shape})")

        except Exception as e:
            print(f"转换失败 {filename}: {str(e)}")
# Out:
# 成功转换: galaxy_image_10003_512.png -> galaxy_image_10003.fit (维度：(512, 512))
# 成功转换: galaxy_image_1000_512.png -> galaxy_image_1000.fit (维度：(512, 512))
# 成功转换: galaxy_image_10031_512.png -> galaxy_image_10031.fit (维度：(512, 512))
# 成功转换: galaxy_image_10034_512.png -> galaxy_image_10034.fit (维度：(512, 512))
# 成功转换: galaxy_image_10046_512.png -> galaxy_image_10046.fit (维度：(512, 512))
# 成功转换: galaxy_image_10061_512.png -> galaxy_image_10061.fit (维度：(512, 512))
# 成功转换: galaxy_image_10073_512.png -> galaxy_image_10073.fit (维度：(512, 512))
# 成功转换: galaxy_image_10081_512.png -> galaxy_image_10081.fit (维度：(512, 512))
# 成功转换: galaxy_image_10085_512.png -> galaxy_image_10085.fit (维度：(512, 512))
# 成功转换: galaxy_image_10090_512.png -> galaxy_image_10090.fit (维度：(512, 512))
# 成功转换: galaxy_image_10092_512.png -> galaxy_image_10092.fit (维度：(512, 512))
# 成功转换: galaxy_image_10093_512.png -> galaxy_image_10093.fit (维度：(512, 512))
# 成功转换: galaxy_image_10094_512.png -> galaxy_image_10094.fit (维度：(512, 512))
# 成功转换: galaxy_image_10101_512.png -> galaxy_image_10101.fit (维度：(512, 512))
# 成功转换: galaxy_image_10107_512.png -> galaxy_image_10107.fit (维度：(512, 512))
# 成功转换: galaxy_image_10108_512.png -> galaxy_image_10108.fit (维度：(512, 512))
# 成功转换: galaxy_image_10109_512.png -> galaxy_image_10109.fit (维度：(512, 512))
# 成功转换: galaxy_image_1011_512.png -> galaxy_image_1011.fit (维度：(512, 512))
# 成功转换: galaxy_image_10121_512.png -> galaxy_image_10121.fit (维度：(512, 512))
# 成功转换: galaxy_image_10127_512.png -> galaxy_image_10127.fit (维度：(512, 512))
# 成功转换: galaxy_image_10130_512.png -> galaxy_image_10130.fit (维度：(512, 512))
# 成功转换: galaxy_image_10134_512.png -> galaxy_image_10134.fit (维度：(512, 512))
# 成功转换: galaxy_image_10140_512.png -> galaxy_image_10140.fit (维度：(512, 512))
# 成功转换: galaxy_image_10142_512.png -> galaxy_image_10142.fit (维度：(512, 512))
# 成功转换: galaxy_image_1014_512.png -> galaxy_image_1014.fit (维度：(512, 512))
# 成功转换: galaxy_image_10166_512.png -> galaxy_image_10166.fit (维度：(512, 512))
# 成功转换: galaxy_image_10180_512.png -> galaxy_image_10180.fit (维度：(512, 512))
# 成功转换: galaxy_image_10190_512.png -> galaxy_image_10190.fit (维度：(512, 512))
# 成功转换: galaxy_image_10195_512.png -> galaxy_image_10195.fit (维度：(512, 512))
# 成功转换: galaxy_image_10200_512.png -> galaxy_image_10200.fit (维度：(512, 512))
# 成功转换: galaxy_image_10217_512.png -> galaxy_image_10217.fit (维度：(512, 512))
# 成功转换: galaxy_image_10228_512.png -> galaxy_image_10228.fit (维度：(512, 512))
# 成功转换: galaxy_image_10233_512.png -> galaxy_image_10233.fit (维度：(512, 512))
# 成功转换: galaxy_image_10235_512.png -> galaxy_image_10235.fit (维度：(512, 512))
# 成功转换: galaxy_image_10243_512.png -> galaxy_image_10243.fit (维度：(512, 512))
# 成功转换: galaxy_image_10246_512.png -> galaxy_image_10246.fit (维度：(512, 512))
# 成功转换: galaxy_image_10248_512.png -> galaxy_image_10248.fit (维度：(512, 512))
# 成功转换: galaxy_image_10253_512.png -> galaxy_image_10253.fit (维度：(512, 512))
# 成功转换: galaxy_image_10256_512.png -> galaxy_image_10256.fit (维度：(512, 512))
# 成功转换: galaxy_image_10258_512.png -> galaxy_image_10258.fit (维度：(512, 512))
# 成功转换: galaxy_image_10261_512.png -> galaxy_image_10261.fit (维度：(512, 512))
# 成功转换: galaxy_image_10265_512.png -> galaxy_image_10265.fit (维度：(512, 512))
# 成功转换: galaxy_image_10266_512.png -> galaxy_image_10266.fit (维度：(512, 512))
# 成功转换: galaxy_image_10267_512.png -> galaxy_image_10267.fit (维度：(512, 512))
# 成功转换: galaxy_image_10296_512.png -> galaxy_image_10296.fit (维度：(512, 512))
# 成功转换: galaxy_image_10306_512.png -> galaxy_image_10306.fit (维度：(512, 512))
# 成功转换: galaxy_image_10308_512.png -> galaxy_image_10308.fit (维度：(512, 512))
# 成功转换: galaxy_image_1030_512.png -> galaxy_image_1030.fit (维度：(512, 512))
# 成功转换: galaxy_image_10312_512.png -> galaxy_image_10312.fit (维度：(512, 512))
# 成功转换: galaxy_image_10317_512.png -> galaxy_image_10317.fit (维度：(512, 512))
# 成功转换: galaxy_image_1031_512.png -> galaxy_image_1031.fit (维度：(512, 512))
# 成功转换: galaxy_image_10322_512.png -> galaxy_image_10322.fit (维度：(512, 512))
# 成功转换: galaxy_image_10323_512.png -> galaxy_image_10323.fit (维度：(512, 512))
# 成功转换: galaxy_image_10337_512.png -> galaxy_image_10337.fit (维度：(512, 512))
# 成功转换: galaxy_image_10340_512.png -> galaxy_image_10340.fit (维度：(512, 512))
# 成功转换: galaxy_image_10349_512.png -> galaxy_image_10349.fit (维度：(512, 512))
# 成功转换: galaxy_image_10351_512.png -> galaxy_image_10351.fit (维度：(512, 512))
# 成功转换: galaxy_image_10367_512.png -> galaxy_image_10367.fit (维度：(512, 512))
# 成功转换: galaxy_image_10369_512.png -> galaxy_image_10369.fit (维度：(512, 512))
# 成功转换: galaxy_image_10375_512.png -> galaxy_image_10375.fit (维度：(512, 512))
# 成功转换: galaxy_image_10378_512.png -> galaxy_image_10378.fit (维度：(512, 512))
# 成功转换: galaxy_image_10385_512.png -> galaxy_image_10385.fit (维度：(512, 512))
# 成功转换: galaxy_image_10386_512.png -> galaxy_image_10386.fit (维度：(512, 512))
# 成功转换: galaxy_image_10387_512.png -> galaxy_image_10387.fit (维度：(512, 512))
# 成功转换: galaxy_image_10390_512.png -> galaxy_image_10390.fit (维度：(512, 512))
# 成功转换: galaxy_image_10403_512.png -> galaxy_image_10403.fit (维度：(512, 512))
# 成功转换: galaxy_image_10404_512.png -> galaxy_image_10404.fit (维度：(512, 512))
# 成功转换: galaxy_image_10408_512.png -> galaxy_image_10408.fit (维度：(512, 512))
# 成功转换: galaxy_image_1040_512.png -> galaxy_image_1040.fit (维度：(512, 512))
# 成功转换: galaxy_image_10414_512.png -> galaxy_image_10414.fit (维度：(512, 512))
# 成功转换: galaxy_image_1042_512.png -> galaxy_image_1042.fit (维度：(512, 512))
# 成功转换: galaxy_image_10430_512.png -> galaxy_image_10430.fit (维度：(512, 512))
# 成功转换: galaxy_image_10458_512.png -> galaxy_image_10458.fit (维度：(512, 512))
# 成功转换: galaxy_image_10459_512.png -> galaxy_image_10459.fit (维度：(512, 512))
# 成功转换: galaxy_image_10463_512.png -> galaxy_image_10463.fit (维度：(512, 512))
# 成功转换: galaxy_image_10466_512.png -> galaxy_image_10466.fit (维度：(512, 512))
# 成功转换: galaxy_image_10473_512.png -> galaxy_image_10473.fit (维度：(512, 512))
# 成功转换: galaxy_image_1047_512.png -> galaxy_image_1047.fit (维度：(512, 512))
# 成功转换: galaxy_image_10481_512.png -> galaxy_image_10481.fit (维度：(512, 512))
# 成功转换: galaxy_image_10483_512.png -> galaxy_image_10483.fit (维度：(512, 512))
# 成功转换: galaxy_image_10487_512.png -> galaxy_image_10487.fit (维度：(512, 512))
# 成功转换: galaxy_image_10488_512.png -> galaxy_image_10488.fit (维度：(512, 512))
# 成功转换: galaxy_image_10490_512.png -> galaxy_image_10490.fit (维度：(512, 512))
# 成功转换: galaxy_image_10500_512.png -> galaxy_image_10500.fit (维度：(512, 512))
# 成功转换: galaxy_image_10503_512.png -> galaxy_image_10503.fit (维度：(512, 512))
# 成功转换: galaxy_image_10508_512.png -> galaxy_image_10508.fit (维度：(512, 512))
# 成功转换: galaxy_image_10514_512.png -> galaxy_image_10514.fit (维度：(512, 512))
# 成功转换: galaxy_image_10518_512.png -> galaxy_image_10518.fit (维度：(512, 512))
# 成功转换: galaxy_image_10534_512.png -> galaxy_image_10534.fit (维度：(512, 512))
# 成功转换: galaxy_image_10543_512.png -> galaxy_image_10543.fit (维度：(512, 512))
# 成功转换: galaxy_image_10558_512.png -> galaxy_image_10558.fit (维度：(512, 512))
# 成功转换: galaxy_image_10559_512.png -> galaxy_image_10559.fit (维度：(512, 512))
# 成功转换: galaxy_image_10560_512.png -> galaxy_image_10560.fit (维度：(512, 512))
# 成功转换: galaxy_image_10561_512.png -> galaxy_image_10561.fit (维度：(512, 512))
# 成功转换: galaxy_image_10571_512.png -> galaxy_image_10571.fit (维度：(512, 512))
# 成功转换: galaxy_image_10575_512.png -> galaxy_image_10575.fit (维度：(512, 512))
# 成功转换: galaxy_image_10579_512.png -> galaxy_image_10579.fit (维度：(512, 512))
# 成功转换: galaxy_image_10587_512.png -> galaxy_image_10587.fit (维度：(512, 512))
# 成功转换: galaxy_image_10590_512.png -> galaxy_image_10590.fit (维度：(512, 512))
# 成功转换: galaxy_image_10591_512.png -> galaxy_image_10591.fit (维度：(512, 512))
# 成功转换: galaxy_image_10601_512.png -> galaxy_image_10601.fit (维度：(512, 512))
# 成功转换: galaxy_image_10609_512.png -> galaxy_image_10609.fit (维度：(512, 512))
# 成功转换: galaxy_image_1060_512.png -> galaxy_image_1060.fit (维度：(512, 512))
# 成功转换: galaxy_image_10614_512.png -> galaxy_image_10614.fit (维度：(512, 512))
# 成功转换: galaxy_image_10615_512.png -> galaxy_image_10615.fit (维度：(512, 512))
# 成功转换: galaxy_image_10622_512.png -> galaxy_image_10622.fit (维度：(512, 512))
# 成功转换: galaxy_image_10630_512.png -> galaxy_image_10630.fit (维度：(512, 512))
# 成功转换: galaxy_image_1063_512.png -> galaxy_image_1063.fit (维度：(512, 512))
# 成功转换: galaxy_image_10640_512.png -> galaxy_image_10640.fit (维度：(512, 512))
# 成功转换: galaxy_image_10645_512.png -> galaxy_image_10645.fit (维度：(512, 512))
# 成功转换: galaxy_image_10646_512.png -> galaxy_image_10646.fit (维度：(512, 512))
# 成功转换: galaxy_image_10648_512.png -> galaxy_image_10648.fit (维度：(512, 512))
# 成功转换: galaxy_image_10663_512.png -> galaxy_image_10663.fit (维度：(512, 512))
# 成功转换: galaxy_image_10672_512.png -> galaxy_image_10672.fit (维度：(512, 512))
# 成功转换: galaxy_image_10683_512.png -> galaxy_image_10683.fit (维度：(512, 512))
# 成功转换: galaxy_image_10686_512.png -> galaxy_image_10686.fit (维度：(512, 512))
# 成功转换: galaxy_image_10688_512.png -> galaxy_image_10688.fit (维度：(512, 512))
# 成功转换: galaxy_image_10705_512.png -> galaxy_image_10705.fit (维度：(512, 512))
# 成功转换: galaxy_image_10706_512.png -> galaxy_image_10706.fit (维度：(512, 512))
# 成功转换: galaxy_image_10711_512.png -> galaxy_image_10711.fit (维度：(512, 512))
# 成功转换: galaxy_image_10719_512.png -> galaxy_image_10719.fit (维度：(512, 512))
# 成功转换: galaxy_image_10729_512.png -> galaxy_image_10729.fit (维度：(512, 512))
# 成功转换: galaxy_image_10747_512.png -> galaxy_image_10747.fit (维度：(512, 512))
# 成功转换: galaxy_image_1074_512.png -> galaxy_image_1074.fit (维度：(512, 512))
# 成功转换: galaxy_image_10762_512.png -> galaxy_image_10762.fit (维度：(512, 512))
# 成功转换: galaxy_image_10777_512.png -> galaxy_image_10777.fit (维度：(512, 512))
# 成功转换: galaxy_image_10786_512.png -> galaxy_image_10786.fit (维度：(512, 512))
# 成功转换: galaxy_image_10794_512.png -> galaxy_image_10794.fit (维度：(512, 512))
# 成功转换: galaxy_image_10795_512.png -> galaxy_image_10795.fit (维度：(512, 512))
# 成功转换: galaxy_image_10796_512.png -> galaxy_image_10796.fit (维度：(512, 512))
# 成功转换: galaxy_image_10802_512.png -> galaxy_image_10802.fit (维度：(512, 512))
# 成功转换: galaxy_image_10803_512.png -> galaxy_image_10803.fit (维度：(512, 512))
# 成功转换: galaxy_image_10822_512.png -> galaxy_image_10822.fit (维度：(512, 512))
# 成功转换: galaxy_image_10826_512.png -> galaxy_image_10826.fit (维度：(512, 512))
# 成功转换: galaxy_image_10832_512.png -> galaxy_image_10832.fit (维度：(512, 512))
# 成功转换: galaxy_image_10839_512.png -> galaxy_image_10839.fit (维度：(512, 512))
# 成功转换: galaxy_image_10843_512.png -> galaxy_image_10843.fit (维度：(512, 512))
# 成功转换: galaxy_image_10862_512.png -> galaxy_image_10862.fit (维度：(512, 512))
# 成功转换: galaxy_image_10863_512.png -> galaxy_image_10863.fit (维度：(512, 512))
# 成功转换: galaxy_image_10875_512.png -> galaxy_image_10875.fit (维度：(512, 512))
# 成功转换: galaxy_image_10877_512.png -> galaxy_image_10877.fit (维度：(512, 512))
# 成功转换: galaxy_image_10884_512.png -> galaxy_image_10884.fit (维度：(512, 512))
# 成功转换: galaxy_image_10898_512.png -> galaxy_image_10898.fit (维度：(512, 512))
# 成功转换: galaxy_image_10908_512.png -> galaxy_image_10908.fit (维度：(512, 512))
# 成功转换: galaxy_image_10909_512.png -> galaxy_image_10909.fit (维度：(512, 512))
# 成功转换: galaxy_image_1090_512.png -> galaxy_image_1090.fit (维度：(512, 512))
# 成功转换: galaxy_image_10911_512.png -> galaxy_image_10911.fit (维度：(512, 512))
# 成功转换: galaxy_image_10917_512.png -> galaxy_image_10917.fit (维度：(512, 512))
# 成功转换: galaxy_image_10928_512.png -> galaxy_image_10928.fit (维度：(512, 512))
# 成功转换: galaxy_image_10930_512.png -> galaxy_image_10930.fit (维度：(512, 512))
# 成功转换: galaxy_image_1093_512.png -> galaxy_image_1093.fit (维度：(512, 512))
# 成功转换: galaxy_image_10951_512.png -> galaxy_image_10951.fit (维度：(512, 512))
# 成功转换: galaxy_image_10955_512.png -> galaxy_image_10955.fit (维度：(512, 512))
# 成功转换: galaxy_image_10971_512.png -> galaxy_image_10971.fit (维度：(512, 512))
# 成功转换: galaxy_image_10977_512.png -> galaxy_image_10977.fit (维度：(512, 512))
# 成功转换: galaxy_image_10978_512.png -> galaxy_image_10978.fit (维度：(512, 512))
# 成功转换: galaxy_image_10980_512.png -> galaxy_image_10980.fit (维度：(512, 512))
# 成功转换: galaxy_image_10982_512.png -> galaxy_image_10982.fit (维度：(512, 512))
# 成功转换: galaxy_image_10988_512.png -> galaxy_image_10988.fit (维度：(512, 512))
# 成功转换: galaxy_image_10992_512.png -> galaxy_image_10992.fit (维度：(512, 512))
# 成功转换: galaxy_image_1099_512.png -> galaxy_image_1099.fit (维度：(512, 512))
# 成功转换: galaxy_image_11007_512.png -> galaxy_image_11007.fit (维度：(512, 512))
# 成功转换: galaxy_image_11013_512.png -> galaxy_image_11013.fit (维度：(512, 512))
# 成功转换: galaxy_image_11027_512.png -> galaxy_image_11027.fit (维度：(512, 512))
# 成功转换: galaxy_image_11045_512.png -> galaxy_image_11045.fit (维度：(512, 512))
# 成功转换: galaxy_image_11050_512.png -> galaxy_image_11050.fit (维度：(512, 512))
# 成功转换: galaxy_image_11054_512.png -> galaxy_image_11054.fit (维度：(512, 512))
# 成功转换: galaxy_image_11057_512.png -> galaxy_image_11057.fit (维度：(512, 512))
# 成功转换: galaxy_image_11067_512.png -> galaxy_image_11067.fit (维度：(512, 512))
# 成功转换: galaxy_image_11071_512.png -> galaxy_image_11071.fit (维度：(512, 512))
# 成功转换: galaxy_image_1107_512.png -> galaxy_image_1107.fit (维度：(512, 512))
# 成功转换: galaxy_image_11085_512.png -> galaxy_image_11085.fit (维度：(512, 512))
# 成功转换: galaxy_image_11086_512.png -> galaxy_image_11086.fit (维度：(512, 512))
# 成功转换: galaxy_image_1108_512.png -> galaxy_image_1108.fit (维度：(512, 512))
# 成功转换: galaxy_image_11093_512.png -> galaxy_image_11093.fit (维度：(512, 512))
# 成功转换: galaxy_image_110_512.png -> galaxy_image_110.fit (维度：(512, 512))
# 成功转换: galaxy_image_1110_512.png -> galaxy_image_1110.fit (维度：(512, 512))
# 成功转换: galaxy_image_1111_512.png -> galaxy_image_1111.fit (维度：(512, 512))
# 成功转换: galaxy_image_11132_512.png -> galaxy_image_11132.fit (维度：(512, 512))
# 成功转换: galaxy_image_11138_512.png -> galaxy_image_11138.fit (维度：(512, 512))
# 成功转换: galaxy_image_11146_512.png -> galaxy_image_11146.fit (维度：(512, 512))
# 成功转换: galaxy_image_11148_512.png -> galaxy_image_11148.fit (维度：(512, 512))
# 成功转换: galaxy_image_11156_512.png -> galaxy_image_11156.fit (维度：(512, 512))
# 成功转换: galaxy_image_11160_512.png -> galaxy_image_11160.fit (维度：(512, 512))
# 成功转换: galaxy_image_11162_512.png -> galaxy_image_11162.fit (维度：(512, 512))
# 成功转换: galaxy_image_11174_512.png -> galaxy_image_11174.fit (维度：(512, 512))
# 成功转换: galaxy_image_11185_512.png -> galaxy_image_11185.fit (维度：(512, 512))
# 成功转换: galaxy_image_11187_512.png -> galaxy_image_11187.fit (维度：(512, 512))
# 成功转换: galaxy_image_1118_512.png -> galaxy_image_1118.fit (维度：(512, 512))
# 成功转换: galaxy_image_11192_512.png -> galaxy_image_11192.fit (维度：(512, 512))
# 成功转换: galaxy_image_11193_512.png -> galaxy_image_11193.fit (维度：(512, 512))
# 成功转换: galaxy_image_11194_512.png -> galaxy_image_11194.fit (维度：(512, 512))
# 成功转换: galaxy_image_11200_512.png -> galaxy_image_11200.fit (维度：(512, 512))
# 成功转换: galaxy_image_11207_512.png -> galaxy_image_11207.fit (维度：(512, 512))
# 成功转换: galaxy_image_11216_512.png -> galaxy_image_11216.fit (维度：(512, 512))
# 成功转换: galaxy_image_1121_512.png -> galaxy_image_1121.fit (维度：(512, 512))
# 成功转换: galaxy_image_11227_512.png -> galaxy_image_11227.fit (维度：(512, 512))
# 成功转换: galaxy_image_11229_512.png -> galaxy_image_11229.fit (维度：(512, 512))
# 成功转换: galaxy_image_11234_512.png -> galaxy_image_11234.fit (维度：(512, 512))
# 成功转换: galaxy_image_11242_512.png -> galaxy_image_11242.fit (维度：(512, 512))
# 成功转换: galaxy_image_11251_512.png -> galaxy_image_11251.fit (维度：(512, 512))
# 成功转换: galaxy_image_11252_512.png -> galaxy_image_11252.fit (维度：(512, 512))
# 成功转换: galaxy_image_11257_512.png -> galaxy_image_11257.fit (维度：(512, 512))
# 成功转换: galaxy_image_11263_512.png -> galaxy_image_11263.fit (维度：(512, 512))
# 成功转换: galaxy_image_11280_512.png -> galaxy_image_11280.fit (维度：(512, 512))
# 成功转换: galaxy_image_11287_512.png -> galaxy_image_11287.fit (维度：(512, 512))
# 成功转换: galaxy_image_1128_512.png -> galaxy_image_1128.fit (维度：(512, 512))
# 成功转换: galaxy_image_11291_512.png -> galaxy_image_11291.fit (维度：(512, 512))
# 成功转换: galaxy_image_11301_512.png -> galaxy_image_11301.fit (维度：(512, 512))
# 成功转换: galaxy_image_11303_512.png -> galaxy_image_11303.fit (维度：(512, 512))
# 成功转换: galaxy_image_11314_512.png -> galaxy_image_11314.fit (维度：(512, 512))
# 成功转换: galaxy_image_11322_512.png -> galaxy_image_11322.fit (维度：(512, 512))
# 成功转换: galaxy_image_11324_512.png -> galaxy_image_11324.fit (维度：(512, 512))
# 成功转换: galaxy_image_11334_512.png -> galaxy_image_11334.fit (维度：(512, 512))
# 成功转换: galaxy_image_11348_512.png -> galaxy_image_11348.fit (维度：(512, 512))
# 成功转换: galaxy_image_11350_512.png -> galaxy_image_11350.fit (维度：(512, 512))
# 成功转换: galaxy_image_11358_512.png -> galaxy_image_11358.fit (维度：(512, 512))
# 成功转换: galaxy_image_11373_512.png -> galaxy_image_11373.fit (维度：(512, 512))
# 成功转换: galaxy_image_11388_512.png -> galaxy_image_11388.fit (维度：(512, 512))
# 成功转换: galaxy_image_11391_512.png -> galaxy_image_11391.fit (维度：(512, 512))
# 成功转换: galaxy_image_11398_512.png -> galaxy_image_11398.fit (维度：(512, 512))
# 成功转换: galaxy_image_11399_512.png -> galaxy_image_11399.fit (维度：(512, 512))
# 成功转换: galaxy_image_113_512.png -> galaxy_image_113.fit (维度：(512, 512))
# 成功转换: galaxy_image_11423_512.png -> galaxy_image_11423.fit (维度：(512, 512))
# 成功转换: galaxy_image_11426_512.png -> galaxy_image_11426.fit (维度：(512, 512))
# 成功转换: galaxy_image_11432_512.png -> galaxy_image_11432.fit (维度：(512, 512))
# 成功转换: galaxy_image_11453_512.png -> galaxy_image_11453.fit (维度：(512, 512))
# 成功转换: galaxy_image_11456_512.png -> galaxy_image_11456.fit (维度：(512, 512))
# 成功转换: galaxy_image_11459_512.png -> galaxy_image_11459.fit (维度：(512, 512))
# 成功转换: galaxy_image_11466_512.png -> galaxy_image_11466.fit (维度：(512, 512))
# 成功转换: galaxy_image_11470_512.png -> galaxy_image_11470.fit (维度：(512, 512))
# 成功转换: galaxy_image_11477_512.png -> galaxy_image_11477.fit (维度：(512, 512))
# 成功转换: galaxy_image_11491_512.png -> galaxy_image_11491.fit (维度：(512, 512))
# 成功转换: galaxy_image_11493_512.png -> galaxy_image_11493.fit (维度：(512, 512))
# 成功转换: galaxy_image_11505_512.png -> galaxy_image_11505.fit (维度：(512, 512))
# 成功转换: galaxy_image_11508_512.png -> galaxy_image_11508.fit (维度：(512, 512))
# 成功转换: galaxy_image_1150_512.png -> galaxy_image_1150.fit (维度：(512, 512))
# 成功转换: galaxy_image_11512_512.png -> galaxy_image_11512.fit (维度：(512, 512))
# 成功转换: galaxy_image_1151_512.png -> galaxy_image_1151.fit (维度：(512, 512))
# 成功转换: galaxy_image_11525_512.png -> galaxy_image_11525.fit (维度：(512, 512))
# 成功转换: galaxy_image_1152_512.png -> galaxy_image_1152.fit (维度：(512, 512))
# 成功转换: galaxy_image_11533_512.png -> galaxy_image_11533.fit (维度：(512, 512))
# 成功转换: galaxy_image_11535_512.png -> galaxy_image_11535.fit (维度：(512, 512))
# 成功转换: galaxy_image_11542_512.png -> galaxy_image_11542.fit (维度：(512, 512))
# 成功转换: galaxy_image_11543_512.png -> galaxy_image_11543.fit (维度：(512, 512))
# 成功转换: galaxy_image_11546_512.png -> galaxy_image_11546.fit (维度：(512, 512))
# 成功转换: galaxy_image_11550_512.png -> galaxy_image_11550.fit (维度：(512, 512))
# 成功转换: galaxy_image_11560_512.png -> galaxy_image_11560.fit (维度：(512, 512))
# 成功转换: galaxy_image_11568_512.png -> galaxy_image_11568.fit (维度：(512, 512))
# 成功转换: galaxy_image_11585_512.png -> galaxy_image_11585.fit (维度：(512, 512))
# 成功转换: galaxy_image_11597_512.png -> galaxy_image_11597.fit (维度：(512, 512))
# 成功转换: galaxy_image_11602_512.png -> galaxy_image_11602.fit (维度：(512, 512))
# 成功转换: galaxy_image_11603_512.png -> galaxy_image_11603.fit (维度：(512, 512))
# 成功转换: galaxy_image_11620_512.png -> galaxy_image_11620.fit (维度：(512, 512))
# 成功转换: galaxy_image_11628_512.png -> galaxy_image_11628.fit (维度：(512, 512))
# 成功转换: galaxy_image_11634_512.png -> galaxy_image_11634.fit (维度：(512, 512))
# 成功转换: galaxy_image_11636_512.png -> galaxy_image_11636.fit (维度：(512, 512))
# 成功转换: galaxy_image_11639_512.png -> galaxy_image_11639.fit (维度：(512, 512))
# 成功转换: galaxy_image_11640_512.png -> galaxy_image_11640.fit (维度：(512, 512))
# 成功转换: galaxy_image_11645_512.png -> galaxy_image_11645.fit (维度：(512, 512))
# 成功转换: galaxy_image_11648_512.png -> galaxy_image_11648.fit (维度：(512, 512))
# 成功转换: galaxy_image_1165_512.png -> galaxy_image_1165.fit (维度：(512, 512))
# 成功转换: galaxy_image_11662_512.png -> galaxy_image_11662.fit (维度：(512, 512))
# 成功转换: galaxy_image_11663_512.png -> galaxy_image_11663.fit (维度：(512, 512))
# 成功转换: galaxy_image_11667_512.png -> galaxy_image_11667.fit (维度：(512, 512))
# 成功转换: galaxy_image_11676_512.png -> galaxy_image_11676.fit (维度：(512, 512))
# 成功转换: galaxy_image_11677_512.png -> galaxy_image_11677.fit (维度：(512, 512))
# 成功转换: galaxy_image_11689_512.png -> galaxy_image_11689.fit (维度：(512, 512))
# 成功转换: galaxy_image_11710_512.png -> galaxy_image_11710.fit (维度：(512, 512))
# 成功转换: galaxy_image_11714_512.png -> galaxy_image_11714.fit (维度：(512, 512))
# 成功转换: galaxy_image_11715_512.png -> galaxy_image_11715.fit (维度：(512, 512))
# 成功转换: galaxy_image_11718_512.png -> galaxy_image_11718.fit (维度：(512, 512))
# 成功转换: galaxy_image_11719_512.png -> galaxy_image_11719.fit (维度：(512, 512))
# 成功转换: galaxy_image_11728_512.png -> galaxy_image_11728.fit (维度：(512, 512))
# 成功转换: galaxy_image_11729_512.png -> galaxy_image_11729.fit (维度：(512, 512))
# 成功转换: galaxy_image_1172_512.png -> galaxy_image_1172.fit (维度：(512, 512))
# 成功转换: galaxy_image_11732_512.png -> galaxy_image_11732.fit (维度：(512, 512))
# 成功转换: galaxy_image_11736_512.png -> galaxy_image_11736.fit (维度：(512, 512))
# 成功转换: galaxy_image_11737_512.png -> galaxy_image_11737.fit (维度：(512, 512))
# 成功转换: galaxy_image_11756_512.png -> galaxy_image_11756.fit (维度：(512, 512))
# 成功转换: galaxy_image_11771_512.png -> galaxy_image_11771.fit (维度：(512, 512))
# 成功转换: galaxy_image_11775_512.png -> galaxy_image_11775.fit (维度：(512, 512))
# 成功转换: galaxy_image_11798_512.png -> galaxy_image_11798.fit (维度：(512, 512))
# 成功转换: galaxy_image_11803_512.png -> galaxy_image_11803.fit (维度：(512, 512))
# 成功转换: galaxy_image_11807_512.png -> galaxy_image_11807.fit (维度：(512, 512))
# 成功转换: galaxy_image_11816_512.png -> galaxy_image_11816.fit (维度：(512, 512))
# 成功转换: galaxy_image_11817_512.png -> galaxy_image_11817.fit (维度：(512, 512))
# 成功转换: galaxy_image_11821_512.png -> galaxy_image_11821.fit (维度：(512, 512))
# 成功转换: galaxy_image_11824_512.png -> galaxy_image_11824.fit (维度：(512, 512))
# 成功转换: galaxy_image_11829_512.png -> galaxy_image_11829.fit (维度：(512, 512))
# 成功转换: galaxy_image_11839_512.png -> galaxy_image_11839.fit (维度：(512, 512))
# 成功转换: galaxy_image_1186_512.png -> galaxy_image_1186.fit (维度：(512, 512))
# 成功转换: galaxy_image_11876_512.png -> galaxy_image_11876.fit (维度：(512, 512))
# 成功转换: galaxy_image_11882_512.png -> galaxy_image_11882.fit (维度：(512, 512))
# 成功转换: galaxy_image_11894_512.png -> galaxy_image_11894.fit (维度：(512, 512))
# 成功转换: galaxy_image_11895_512.png -> galaxy_image_11895.fit (维度：(512, 512))
# 成功转换: galaxy_image_11899_512.png -> galaxy_image_11899.fit (维度：(512, 512))
# 成功转换: galaxy_image_11922_512.png -> galaxy_image_11922.fit (维度：(512, 512))
# 成功转换: galaxy_image_11934_512.png -> galaxy_image_11934.fit (维度：(512, 512))
# 成功转换: galaxy_image_11937_512.png -> galaxy_image_11937.fit (维度：(512, 512))
# 成功转换: galaxy_image_1193_512.png -> galaxy_image_1193.fit (维度：(512, 512))
# 成功转换: galaxy_image_11940_512.png -> galaxy_image_11940.fit (维度：(512, 512))
# 成功转换: galaxy_image_11941_512.png -> galaxy_image_11941.fit (维度：(512, 512))
# 成功转换: galaxy_image_11949_512.png -> galaxy_image_11949.fit (维度：(512, 512))
# 成功转换: galaxy_image_11951_512.png -> galaxy_image_11951.fit (维度：(512, 512))
# 成功转换: galaxy_image_11953_512.png -> galaxy_image_11953.fit (维度：(512, 512))
# 成功转换: galaxy_image_11960_512.png -> galaxy_image_11960.fit (维度：(512, 512))
# 成功转换: galaxy_image_11962_512.png -> galaxy_image_11962.fit (维度：(512, 512))
# 成功转换: galaxy_image_11967_512.png -> galaxy_image_11967.fit (维度：(512, 512))
# 成功转换: galaxy_image_11976_512.png -> galaxy_image_11976.fit (维度：(512, 512))
# 成功转换: galaxy_image_11983_512.png -> galaxy_image_11983.fit (维度：(512, 512))
# 成功转换: galaxy_image_11985_512.png -> galaxy_image_11985.fit (维度：(512, 512))
# 成功转换: galaxy_image_11993_512.png -> galaxy_image_11993.fit (维度：(512, 512))
# 成功转换: galaxy_image_11994_512.png -> galaxy_image_11994.fit (维度：(512, 512))
# 成功转换: galaxy_image_1199_512.png -> galaxy_image_1199.fit (维度：(512, 512))
# 成功转换: galaxy_image_12007_512.png -> galaxy_image_12007.fit (维度：(512, 512))
# 成功转换: galaxy_image_12008_512.png -> galaxy_image_12008.fit (维度：(512, 512))
# 成功转换: galaxy_image_1200_512.png -> galaxy_image_1200.fit (维度：(512, 512))
# 成功转换: galaxy_image_12017_512.png -> galaxy_image_12017.fit (维度：(512, 512))
# 成功转换: galaxy_image_12026_512.png -> galaxy_image_12026.fit (维度：(512, 512))
# 成功转换: galaxy_image_1202_512.png -> galaxy_image_1202.fit (维度：(512, 512))
# 成功转换: galaxy_image_12030_512.png -> galaxy_image_12030.fit (维度：(512, 512))
# 成功转换: galaxy_image_12037_512.png -> galaxy_image_12037.fit (维度：(512, 512))
# 成功转换: galaxy_image_12038_512.png -> galaxy_image_12038.fit (维度：(512, 512))
# 成功转换: galaxy_image_12040_512.png -> galaxy_image_12040.fit (维度：(512, 512))
# 成功转换: galaxy_image_12042_512.png -> galaxy_image_12042.fit (维度：(512, 512))
# 成功转换: galaxy_image_12043_512.png -> galaxy_image_12043.fit (维度：(512, 512))
# 成功转换: galaxy_image_12048_512.png -> galaxy_image_12048.fit (维度：(512, 512))
# 成功转换: galaxy_image_12051_512.png -> galaxy_image_12051.fit (维度：(512, 512))
# 成功转换: galaxy_image_12053_512.png -> galaxy_image_12053.fit (维度：(512, 512))
# 成功转换: galaxy_image_1205_512.png -> galaxy_image_1205.fit (维度：(512, 512))
# 成功转换: galaxy_image_12067_512.png -> galaxy_image_12067.fit (维度：(512, 512))
# 成功转换: galaxy_image_1206_512.png -> galaxy_image_1206.fit (维度：(512, 512))
# 成功转换: galaxy_image_12084_512.png -> galaxy_image_12084.fit (维度：(512, 512))
# 成功转换: galaxy_image_12086_512.png -> galaxy_image_12086.fit (维度：(512, 512))
# 成功转换: galaxy_image_12093_512.png -> galaxy_image_12093.fit (维度：(512, 512))
# 成功转换: galaxy_image_12103_512.png -> galaxy_image_12103.fit (维度：(512, 512))
# 成功转换: galaxy_image_12112_512.png -> galaxy_image_12112.fit (维度：(512, 512))
# 成功转换: galaxy_image_1211_512.png -> galaxy_image_1211.fit (维度：(512, 512))
# 成功转换: galaxy_image_1212_512.png -> galaxy_image_1212.fit (维度：(512, 512))
# 成功转换: galaxy_image_12132_512.png -> galaxy_image_12132.fit (维度：(512, 512))
# 成功转换: galaxy_image_12135_512.png -> galaxy_image_12135.fit (维度：(512, 512))
# 成功转换: galaxy_image_12149_512.png -> galaxy_image_12149.fit (维度：(512, 512))
# 成功转换: galaxy_image_12153_512.png -> galaxy_image_12153.fit (维度：(512, 512))
# 成功转换: galaxy_image_12157_512.png -> galaxy_image_12157.fit (维度：(512, 512))
# 成功转换: galaxy_image_12171_512.png -> galaxy_image_12171.fit (维度：(512, 512))
# 成功转换: galaxy_image_1217_512.png -> galaxy_image_1217.fit (维度：(512, 512))
# 成功转换: galaxy_image_12180_512.png -> galaxy_image_12180.fit (维度：(512, 512))
# 成功转换: galaxy_image_12183_512.png -> galaxy_image_12183.fit (维度：(512, 512))
# 成功转换: galaxy_image_12185_512.png -> galaxy_image_12185.fit (维度：(512, 512))
# 成功转换: galaxy_image_12190_512.png -> galaxy_image_12190.fit (维度：(512, 512))
# 成功转换: galaxy_image_12200_512.png -> galaxy_image_12200.fit (维度：(512, 512))
# 成功转换: galaxy_image_12204_512.png -> galaxy_image_12204.fit (维度：(512, 512))
# 成功转换: galaxy_image_12206_512.png -> galaxy_image_12206.fit (维度：(512, 512))
# 成功转换: galaxy_image_12217_512.png -> galaxy_image_12217.fit (维度：(512, 512))
# 成功转换: galaxy_image_12227_512.png -> galaxy_image_12227.fit (维度：(512, 512))
# 成功转换: galaxy_image_12235_512.png -> galaxy_image_12235.fit (维度：(512, 512))
# 成功转换: galaxy_image_12239_512.png -> galaxy_image_12239.fit (维度：(512, 512))
# 成功转换: galaxy_image_1223_512.png -> galaxy_image_1223.fit (维度：(512, 512))
# 成功转换: galaxy_image_12241_512.png -> galaxy_image_12241.fit (维度：(512, 512))
# 成功转换: galaxy_image_12267_512.png -> galaxy_image_12267.fit (维度：(512, 512))
# 成功转换: galaxy_image_12276_512.png -> galaxy_image_12276.fit (维度：(512, 512))
# 成功转换: galaxy_image_12280_512.png -> galaxy_image_12280.fit (维度：(512, 512))
# 成功转换: galaxy_image_12288_512.png -> galaxy_image_12288.fit (维度：(512, 512))
# 成功转换: galaxy_image_12290_512.png -> galaxy_image_12290.fit (维度：(512, 512))
# 成功转换: galaxy_image_12291_512.png -> galaxy_image_12291.fit (维度：(512, 512))
# 成功转换: galaxy_image_12293_512.png -> galaxy_image_12293.fit (维度：(512, 512))
# 成功转换: galaxy_image_12303_512.png -> galaxy_image_12303.fit (维度：(512, 512))
# 成功转换: galaxy_image_12310_512.png -> galaxy_image_12310.fit (维度：(512, 512))
# 成功转换: galaxy_image_12311_512.png -> galaxy_image_12311.fit (维度：(512, 512))
# 成功转换: galaxy_image_12314_512.png -> galaxy_image_12314.fit (维度：(512, 512))
# 成功转换: galaxy_image_12319_512.png -> galaxy_image_12319.fit (维度：(512, 512))
# 成功转换: galaxy_image_12323_512.png -> galaxy_image_12323.fit (维度：(512, 512))
# 成功转换: galaxy_image_12325_512.png -> galaxy_image_12325.fit (维度：(512, 512))
# 成功转换: galaxy_image_12334_512.png -> galaxy_image_12334.fit (维度：(512, 512))
# 成功转换: galaxy_image_12335_512.png -> galaxy_image_12335.fit (维度：(512, 512))
# 成功转换: galaxy_image_12336_512.png -> galaxy_image_12336.fit (维度：(512, 512))
# 成功转换: galaxy_image_12337_512.png -> galaxy_image_12337.fit (维度：(512, 512))
# 成功转换: galaxy_image_12339_512.png -> galaxy_image_12339.fit (维度：(512, 512))
# 成功转换: galaxy_image_12348_512.png -> galaxy_image_12348.fit (维度：(512, 512))
# 成功转换: galaxy_image_12356_512.png -> galaxy_image_12356.fit (维度：(512, 512))
# 成功转换: galaxy_image_12358_512.png -> galaxy_image_12358.fit (维度：(512, 512))
# 成功转换: galaxy_image_12364_512.png -> galaxy_image_12364.fit (维度：(512, 512))
# 成功转换: galaxy_image_12368_512.png -> galaxy_image_12368.fit (维度：(512, 512))
# 成功转换: galaxy_image_12370_512.png -> galaxy_image_12370.fit (维度：(512, 512))
# 成功转换: galaxy_image_12378_512.png -> galaxy_image_12378.fit (维度：(512, 512))
# 成功转换: galaxy_image_12383_512.png -> galaxy_image_12383.fit (维度：(512, 512))
# 成功转换: galaxy_image_12403_512.png -> galaxy_image_12403.fit (维度：(512, 512))
# 成功转换: galaxy_image_12417_512.png -> galaxy_image_12417.fit (维度：(512, 512))
# 成功转换: galaxy_image_1242_512.png -> galaxy_image_1242.fit (维度：(512, 512))
# 成功转换: galaxy_image_12441_512.png -> galaxy_image_12441.fit (维度：(512, 512))
# 成功转换: galaxy_image_12448_512.png -> galaxy_image_12448.fit (维度：(512, 512))
# 成功转换: galaxy_image_12463_512.png -> galaxy_image_12463.fit (维度：(512, 512))
# 成功转换: galaxy_image_12473_512.png -> galaxy_image_12473.fit (维度：(512, 512))
# 成功转换: galaxy_image_12474_512.png -> galaxy_image_12474.fit (维度：(512, 512))
# 成功转换: galaxy_image_12491_512.png -> galaxy_image_12491.fit (维度：(512, 512))
# 成功转换: galaxy_image_1249_512.png -> galaxy_image_1249.fit (维度：(512, 512))
# 成功转换: galaxy_image_1251_512.png -> galaxy_image_1251.fit (维度：(512, 512))
# 成功转换: galaxy_image_12521_512.png -> galaxy_image_12521.fit (维度：(512, 512))
# 成功转换: galaxy_image_12526_512.png -> galaxy_image_12526.fit (维度：(512, 512))
# 成功转换: galaxy_image_12530_512.png -> galaxy_image_12530.fit (维度：(512, 512))
# 成功转换: galaxy_image_12539_512.png -> galaxy_image_12539.fit (维度：(512, 512))
# 成功转换: galaxy_image_12541_512.png -> galaxy_image_12541.fit (维度：(512, 512))
# 成功转换: galaxy_image_12551_512.png -> galaxy_image_12551.fit (维度：(512, 512))
# 成功转换: galaxy_image_12552_512.png -> galaxy_image_12552.fit (维度：(512, 512))
# 成功转换: galaxy_image_12555_512.png -> galaxy_image_12555.fit (维度：(512, 512))
# 成功转换: galaxy_image_12557_512.png -> galaxy_image_12557.fit (维度：(512, 512))
# 成功转换: galaxy_image_12565_512.png -> galaxy_image_12565.fit (维度：(512, 512))
# 成功转换: galaxy_image_12570_512.png -> galaxy_image_12570.fit (维度：(512, 512))
# 成功转换: galaxy_image_1257_512.png -> galaxy_image_1257.fit (维度：(512, 512))
# 成功转换: galaxy_image_12583_512.png -> galaxy_image_12583.fit (维度：(512, 512))
# 成功转换: galaxy_image_1258_512.png -> galaxy_image_1258.fit (维度：(512, 512))
# 成功转换: galaxy_image_12591_512.png -> galaxy_image_12591.fit (维度：(512, 512))
# 成功转换: galaxy_image_12592_512.png -> galaxy_image_12592.fit (维度：(512, 512))
# 成功转换: galaxy_image_1259_512.png -> galaxy_image_1259.fit (维度：(512, 512))
# 成功转换: galaxy_image_12612_512.png -> galaxy_image_12612.fit (维度：(512, 512))
# 成功转换: galaxy_image_12624_512.png -> galaxy_image_12624.fit (维度：(512, 512))
# 成功转换: galaxy_image_1262_512.png -> galaxy_image_1262.fit (维度：(512, 512))
# 成功转换: galaxy_image_12631_512.png -> galaxy_image_12631.fit (维度：(512, 512))
# 成功转换: galaxy_image_12635_512.png -> galaxy_image_12635.fit (维度：(512, 512))
# 成功转换: galaxy_image_12645_512.png -> galaxy_image_12645.fit (维度：(512, 512))
# 成功转换: galaxy_image_12649_512.png -> galaxy_image_12649.fit (维度：(512, 512))
# 成功转换: galaxy_image_1264_512.png -> galaxy_image_1264.fit (维度：(512, 512))
# 成功转换: galaxy_image_12650_512.png -> galaxy_image_12650.fit (维度：(512, 512))
# 成功转换: galaxy_image_12654_512.png -> galaxy_image_12654.fit (维度：(512, 512))
# 成功转换: galaxy_image_1266_512.png -> galaxy_image_1266.fit (维度：(512, 512))
# 成功转换: galaxy_image_12671_512.png -> galaxy_image_12671.fit (维度：(512, 512))
# 成功转换: galaxy_image_12675_512.png -> galaxy_image_12675.fit (维度：(512, 512))
# 成功转换: galaxy_image_12686_512.png -> galaxy_image_12686.fit (维度：(512, 512))
# 成功转换: galaxy_image_12703_512.png -> galaxy_image_12703.fit (维度：(512, 512))
# 成功转换: galaxy_image_1270_512.png -> galaxy_image_1270.fit (维度：(512, 512))
# 成功转换: galaxy_image_12711_512.png -> galaxy_image_12711.fit (维度：(512, 512))
# 成功转换: galaxy_image_12716_512.png -> galaxy_image_12716.fit (维度：(512, 512))
# 成功转换: galaxy_image_12720_512.png -> galaxy_image_12720.fit (维度：(512, 512))
# 成功转换: galaxy_image_12737_512.png -> galaxy_image_12737.fit (维度：(512, 512))
# 成功转换: galaxy_image_12738_512.png -> galaxy_image_12738.fit (维度：(512, 512))
# 成功转换: galaxy_image_12749_512.png -> galaxy_image_12749.fit (维度：(512, 512))
# 成功转换: galaxy_image_12756_512.png -> galaxy_image_12756.fit (维度：(512, 512))
# 成功转换: galaxy_image_1275_512.png -> galaxy_image_1275.fit (维度：(512, 512))
# 成功转换: galaxy_image_12767_512.png -> galaxy_image_12767.fit (维度：(512, 512))
# 成功转换: galaxy_image_12771_512.png -> galaxy_image_12771.fit (维度：(512, 512))
# 成功转换: galaxy_image_12778_512.png -> galaxy_image_12778.fit (维度：(512, 512))
# 成功转换: galaxy_image_1277_512.png -> galaxy_image_1277.fit (维度：(512, 512))
# 成功转换: galaxy_image_12785_512.png -> galaxy_image_12785.fit (维度：(512, 512))
# 成功转换: galaxy_image_12796_512.png -> galaxy_image_12796.fit (维度：(512, 512))
# 成功转换: galaxy_image_12797_512.png -> galaxy_image_12797.fit (维度：(512, 512))
# 成功转换: galaxy_image_127_512.png -> galaxy_image_127.fit (维度：(512, 512))
# 成功转换: galaxy_image_12800_512.png -> galaxy_image_12800.fit (维度：(512, 512))
# 成功转换: galaxy_image_12808_512.png -> galaxy_image_12808.fit (维度：(512, 512))
# 成功转换: galaxy_image_12817_512.png -> galaxy_image_12817.fit (维度：(512, 512))
# 成功转换: galaxy_image_12818_512.png -> galaxy_image_12818.fit (维度：(512, 512))
# 成功转换: galaxy_image_12824_512.png -> galaxy_image_12824.fit (维度：(512, 512))
# 成功转换: galaxy_image_12827_512.png -> galaxy_image_12827.fit (维度：(512, 512))
# 成功转换: galaxy_image_1282_512.png -> galaxy_image_1282.fit (维度：(512, 512))
# 成功转换: galaxy_image_12841_512.png -> galaxy_image_12841.fit (维度：(512, 512))
# 成功转换: galaxy_image_12842_512.png -> galaxy_image_12842.fit (维度：(512, 512))
# 成功转换: galaxy_image_12843_512.png -> galaxy_image_12843.fit (维度：(512, 512))
# 成功转换: galaxy_image_12848_512.png -> galaxy_image_12848.fit (维度：(512, 512))
# 成功转换: galaxy_image_12857_512.png -> galaxy_image_12857.fit (维度：(512, 512))
# 成功转换: galaxy_image_12858_512.png -> galaxy_image_12858.fit (维度：(512, 512))
# 成功转换: galaxy_image_1285_512.png -> galaxy_image_1285.fit (维度：(512, 512))
# 成功转换: galaxy_image_12860_512.png -> galaxy_image_12860.fit (维度：(512, 512))
# 成功转换: galaxy_image_12862_512.png -> galaxy_image_12862.fit (维度：(512, 512))
# 成功转换: galaxy_image_12870_512.png -> galaxy_image_12870.fit (维度：(512, 512))
# 成功转换: galaxy_image_1287_512.png -> galaxy_image_1287.fit (维度：(512, 512))
# 成功转换: galaxy_image_12884_512.png -> galaxy_image_12884.fit (维度：(512, 512))
# 成功转换: galaxy_image_12892_512.png -> galaxy_image_12892.fit (维度：(512, 512))
# 成功转换: galaxy_image_12894_512.png -> galaxy_image_12894.fit (维度：(512, 512))
# 成功转换: galaxy_image_12898_512.png -> galaxy_image_12898.fit (维度：(512, 512))
# 成功转换: galaxy_image_12900_512.png -> galaxy_image_12900.fit (维度：(512, 512))
# 成功转换: galaxy_image_12901_512.png -> galaxy_image_12901.fit (维度：(512, 512))
# 成功转换: galaxy_image_12911_512.png -> galaxy_image_12911.fit (维度：(512, 512))
# 成功转换: galaxy_image_12912_512.png -> galaxy_image_12912.fit (维度：(512, 512))
# 成功转换: galaxy_image_12919_512.png -> galaxy_image_12919.fit (维度：(512, 512))
# 成功转换: galaxy_image_12933_512.png -> galaxy_image_12933.fit (维度：(512, 512))
# 成功转换: galaxy_image_12940_512.png -> galaxy_image_12940.fit (维度：(512, 512))
# 成功转换: galaxy_image_12942_512.png -> galaxy_image_12942.fit (维度：(512, 512))
# 成功转换: galaxy_image_12944_512.png -> galaxy_image_12944.fit (维度：(512, 512))
# 成功转换: galaxy_image_1294_512.png -> galaxy_image_1294.fit (维度：(512, 512))
# 成功转换: galaxy_image_12966_512.png -> galaxy_image_12966.fit (维度：(512, 512))
# 成功转换: galaxy_image_12967_512.png -> galaxy_image_12967.fit (维度：(512, 512))
# 成功转换: galaxy_image_12969_512.png -> galaxy_image_12969.fit (维度：(512, 512))
# 成功转换: galaxy_image_12973_512.png -> galaxy_image_12973.fit (维度：(512, 512))
# 成功转换: galaxy_image_12980_512.png -> galaxy_image_12980.fit (维度：(512, 512))
# 成功转换: galaxy_image_12991_512.png -> galaxy_image_12991.fit (维度：(512, 512))
# 成功转换: galaxy_image_13006_512.png -> galaxy_image_13006.fit (维度：(512, 512))
# 成功转换: galaxy_image_13012_512.png -> galaxy_image_13012.fit (维度：(512, 512))
# 成功转换: galaxy_image_13025_512.png -> galaxy_image_13025.fit (维度：(512, 512))
# 成功转换: galaxy_image_13036_512.png -> galaxy_image_13036.fit (维度：(512, 512))
# 成功转换: galaxy_image_13045_512.png -> galaxy_image_13045.fit (维度：(512, 512))
# 成功转换: galaxy_image_13058_512.png -> galaxy_image_13058.fit (维度：(512, 512))
# 成功转换: galaxy_image_13063_512.png -> galaxy_image_13063.fit (维度：(512, 512))
# 成功转换: galaxy_image_13066_512.png -> galaxy_image_13066.fit (维度：(512, 512))
# 成功转换: galaxy_image_13075_512.png -> galaxy_image_13075.fit (维度：(512, 512))
# 成功转换: galaxy_image_13077_512.png -> galaxy_image_13077.fit (维度：(512, 512))
# 成功转换: galaxy_image_1307_512.png -> galaxy_image_1307.fit (维度：(512, 512))
# 成功转换: galaxy_image_13080_512.png -> galaxy_image_13080.fit (维度：(512, 512))
# 成功转换: galaxy_image_13086_512.png -> galaxy_image_13086.fit (维度：(512, 512))
# 成功转换: galaxy_image_13087_512.png -> galaxy_image_13087.fit (维度：(512, 512))
# 成功转换: galaxy_image_13097_512.png -> galaxy_image_13097.fit (维度：(512, 512))
# 成功转换: galaxy_image_13098_512.png -> galaxy_image_13098.fit (维度：(512, 512))
# 成功转换: galaxy_image_13099_512.png -> galaxy_image_13099.fit (维度：(512, 512))
# 成功转换: galaxy_image_1309_512.png -> galaxy_image_1309.fit (维度：(512, 512))
# 成功转换: galaxy_image_13100_512.png -> galaxy_image_13100.fit (维度：(512, 512))
# 成功转换: galaxy_image_1310_512.png -> galaxy_image_1310.fit (维度：(512, 512))
# 成功转换: galaxy_image_13110_512.png -> galaxy_image_13110.fit (维度：(512, 512))
# 成功转换: galaxy_image_13120_512.png -> galaxy_image_13120.fit (维度：(512, 512))
# 成功转换: galaxy_image_13126_512.png -> galaxy_image_13126.fit (维度：(512, 512))
# 成功转换: galaxy_image_13128_512.png -> galaxy_image_13128.fit (维度：(512, 512))
# 成功转换: galaxy_image_13133_512.png -> galaxy_image_13133.fit (维度：(512, 512))
# 成功转换: galaxy_image_13134_512.png -> galaxy_image_13134.fit (维度：(512, 512))
# 成功转换: galaxy_image_13148_512.png -> galaxy_image_13148.fit (维度：(512, 512))
# 成功转换: galaxy_image_13153_512.png -> galaxy_image_13153.fit (维度：(512, 512))
# 成功转换: galaxy_image_13161_512.png -> galaxy_image_13161.fit (维度：(512, 512))
# 成功转换: galaxy_image_13174_512.png -> galaxy_image_13174.fit (维度：(512, 512))
# 成功转换: galaxy_image_13175_512.png -> galaxy_image_13175.fit (维度：(512, 512))
# 成功转换: galaxy_image_13181_512.png -> galaxy_image_13181.fit (维度：(512, 512))
# 成功转换: galaxy_image_13187_512.png -> galaxy_image_13187.fit (维度：(512, 512))
# 成功转换: galaxy_image_13190_512.png -> galaxy_image_13190.fit (维度：(512, 512))
# 成功转换: galaxy_image_13204_512.png -> galaxy_image_13204.fit (维度：(512, 512))
# 成功转换: galaxy_image_13217_512.png -> galaxy_image_13217.fit (维度：(512, 512))
# 成功转换: galaxy_image_13221_512.png -> galaxy_image_13221.fit (维度：(512, 512))
# 成功转换: galaxy_image_13233_512.png -> galaxy_image_13233.fit (维度：(512, 512))
# 成功转换: galaxy_image_13234_512.png -> galaxy_image_13234.fit (维度：(512, 512))
# 成功转换: galaxy_image_13239_512.png -> galaxy_image_13239.fit (维度：(512, 512))
# 成功转换: galaxy_image_13241_512.png -> galaxy_image_13241.fit (维度：(512, 512))
# 成功转换: galaxy_image_13243_512.png -> galaxy_image_13243.fit (维度：(512, 512))
# 成功转换: galaxy_image_13252_512.png -> galaxy_image_13252.fit (维度：(512, 512))
# 成功转换: galaxy_image_13253_512.png -> galaxy_image_13253.fit (维度：(512, 512))
# 成功转换: galaxy_image_13267_512.png -> galaxy_image_13267.fit (维度：(512, 512))
# 成功转换: galaxy_image_13272_512.png -> galaxy_image_13272.fit (维度：(512, 512))
# 成功转换: galaxy_image_13273_512.png -> galaxy_image_13273.fit (维度：(512, 512))
# 成功转换: galaxy_image_13274_512.png -> galaxy_image_13274.fit (维度：(512, 512))
# 成功转换: galaxy_image_13285_512.png -> galaxy_image_13285.fit (维度：(512, 512))
# 成功转换: galaxy_image_13294_512.png -> galaxy_image_13294.fit (维度：(512, 512))
# 成功转换: galaxy_image_13300_512.png -> galaxy_image_13300.fit (维度：(512, 512))
# 成功转换: galaxy_image_13301_512.png -> galaxy_image_13301.fit (维度：(512, 512))
# 成功转换: galaxy_image_13302_512.png -> galaxy_image_13302.fit (维度：(512, 512))
# 成功转换: galaxy_image_13303_512.png -> galaxy_image_13303.fit (维度：(512, 512))
# 成功转换: galaxy_image_13311_512.png -> galaxy_image_13311.fit (维度：(512, 512))
# 成功转换: galaxy_image_13317_512.png -> galaxy_image_13317.fit (维度：(512, 512))
# 成功转换: galaxy_image_1331_512.png -> galaxy_image_1331.fit (维度：(512, 512))
# 成功转换: galaxy_image_13328_512.png -> galaxy_image_13328.fit (维度：(512, 512))
# 成功转换: galaxy_image_13333_512.png -> galaxy_image_13333.fit (维度：(512, 512))
# 成功转换: galaxy_image_13337_512.png -> galaxy_image_13337.fit (维度：(512, 512))
# 成功转换: galaxy_image_1333_512.png -> galaxy_image_1333.fit (维度：(512, 512))
# 成功转换: galaxy_image_13341_512.png -> galaxy_image_13341.fit (维度：(512, 512))
# 成功转换: galaxy_image_13343_512.png -> galaxy_image_13343.fit (维度：(512, 512))
# 成功转换: galaxy_image_13344_512.png -> galaxy_image_13344.fit (维度：(512, 512))
# 成功转换: galaxy_image_13352_512.png -> galaxy_image_13352.fit (维度：(512, 512))
# 成功转换: galaxy_image_13356_512.png -> galaxy_image_13356.fit (维度：(512, 512))
# 成功转换: galaxy_image_13358_512.png -> galaxy_image_13358.fit (维度：(512, 512))
# 成功转换: galaxy_image_13369_512.png -> galaxy_image_13369.fit (维度：(512, 512))
# 成功转换: galaxy_image_13374_512.png -> galaxy_image_13374.fit (维度：(512, 512))
# 成功转换: galaxy_image_13385_512.png -> galaxy_image_13385.fit (维度：(512, 512))
# 成功转换: galaxy_image_13397_512.png -> galaxy_image_13397.fit (维度：(512, 512))
# 成功转换: galaxy_image_13411_512.png -> galaxy_image_13411.fit (维度：(512, 512))
# 成功转换: galaxy_image_13413_512.png -> galaxy_image_13413.fit (维度：(512, 512))
# 成功转换: galaxy_image_13415_512.png -> galaxy_image_13415.fit (维度：(512, 512))
# 成功转换: galaxy_image_13416_512.png -> galaxy_image_13416.fit (维度：(512, 512))
# 成功转换: galaxy_image_13419_512.png -> galaxy_image_13419.fit (维度：(512, 512))
# 成功转换: galaxy_image_13425_512.png -> galaxy_image_13425.fit (维度：(512, 512))
# 成功转换: galaxy_image_13429_512.png -> galaxy_image_13429.fit (维度：(512, 512))
# 成功转换: galaxy_image_13430_512.png -> galaxy_image_13430.fit (维度：(512, 512))
# 成功转换: galaxy_image_13434_512.png -> galaxy_image_13434.fit (维度：(512, 512))
# 成功转换: galaxy_image_13439_512.png -> galaxy_image_13439.fit (维度：(512, 512))
# 成功转换: galaxy_image_13449_512.png -> galaxy_image_13449.fit (维度：(512, 512))
# 成功转换: galaxy_image_13460_512.png -> galaxy_image_13460.fit (维度：(512, 512))
# 成功转换: galaxy_image_1346_512.png -> galaxy_image_1346.fit (维度：(512, 512))
# 成功转换: galaxy_image_13470_512.png -> galaxy_image_13470.fit (维度：(512, 512))
# 成功转换: galaxy_image_13481_512.png -> galaxy_image_13481.fit (维度：(512, 512))
# 成功转换: galaxy_image_1348_512.png -> galaxy_image_1348.fit (维度：(512, 512))
# 成功转换: galaxy_image_13490_512.png -> galaxy_image_13490.fit (维度：(512, 512))
# 成功转换: galaxy_image_13492_512.png -> galaxy_image_13492.fit (维度：(512, 512))
# 成功转换: galaxy_image_13504_512.png -> galaxy_image_13504.fit (维度：(512, 512))
# 成功转换: galaxy_image_13508_512.png -> galaxy_image_13508.fit (维度：(512, 512))
# 成功转换: galaxy_image_13520_512.png -> galaxy_image_13520.fit (维度：(512, 512))
# 成功转换: galaxy_image_13522_512.png -> galaxy_image_13522.fit (维度：(512, 512))
# 成功转换: galaxy_image_13523_512.png -> galaxy_image_13523.fit (维度：(512, 512))
# 成功转换: galaxy_image_13526_512.png -> galaxy_image_13526.fit (维度：(512, 512))
# 成功转换: galaxy_image_13527_512.png -> galaxy_image_13527.fit (维度：(512, 512))
# 成功转换: galaxy_image_13540_512.png -> galaxy_image_13540.fit (维度：(512, 512))
# 成功转换: galaxy_image_13544_512.png -> galaxy_image_13544.fit (维度：(512, 512))
# 成功转换: galaxy_image_13562_512.png -> galaxy_image_13562.fit (维度：(512, 512))
# 成功转换: galaxy_image_13564_512.png -> galaxy_image_13564.fit (维度：(512, 512))
# 成功转换: galaxy_image_13596_512.png -> galaxy_image_13596.fit (维度：(512, 512))
# 成功转换: galaxy_image_13605_512.png -> galaxy_image_13605.fit (维度：(512, 512))
# 成功转换: galaxy_image_13609_512.png -> galaxy_image_13609.fit (维度：(512, 512))
# 成功转换: galaxy_image_13615_512.png -> galaxy_image_13615.fit (维度：(512, 512))
# 成功转换: galaxy_image_13617_512.png -> galaxy_image_13617.fit (维度：(512, 512))
# 成功转换: galaxy_image_13623_512.png -> galaxy_image_13623.fit (维度：(512, 512))
# 成功转换: galaxy_image_13631_512.png -> galaxy_image_13631.fit (维度：(512, 512))
# 成功转换: galaxy_image_13639_512.png -> galaxy_image_13639.fit (维度：(512, 512))
# 成功转换: galaxy_image_13644_512.png -> galaxy_image_13644.fit (维度：(512, 512))
# 成功转换: galaxy_image_13648_512.png -> galaxy_image_13648.fit (维度：(512, 512))
# 成功转换: galaxy_image_13650_512.png -> galaxy_image_13650.fit (维度：(512, 512))
# 成功转换: galaxy_image_13658_512.png -> galaxy_image_13658.fit (维度：(512, 512))
# 成功转换: galaxy_image_13659_512.png -> galaxy_image_13659.fit (维度：(512, 512))
# 成功转换: galaxy_image_13660_512.png -> galaxy_image_13660.fit (维度：(512, 512))
# 成功转换: galaxy_image_1366_512.png -> galaxy_image_1366.fit (维度：(512, 512))
# 成功转换: galaxy_image_13697_512.png -> galaxy_image_13697.fit (维度：(512, 512))
# 成功转换: galaxy_image_13708_512.png -> galaxy_image_13708.fit (维度：(512, 512))
# 成功转换: galaxy_image_13714_512.png -> galaxy_image_13714.fit (维度：(512, 512))
# 成功转换: galaxy_image_13723_512.png -> galaxy_image_13723.fit (维度：(512, 512))
# 成功转换: galaxy_image_13731_512.png -> galaxy_image_13731.fit (维度：(512, 512))
# 成功转换: galaxy_image_13733_512.png -> galaxy_image_13733.fit (维度：(512, 512))
# 成功转换: galaxy_image_13736_512.png -> galaxy_image_13736.fit (维度：(512, 512))
# 成功转换: galaxy_image_1376_512.png -> galaxy_image_1376.fit (维度：(512, 512))
# 成功转换: galaxy_image_13776_512.png -> galaxy_image_13776.fit (维度：(512, 512))
# 成功转换: galaxy_image_13807_512.png -> galaxy_image_13807.fit (维度：(512, 512))
# 成功转换: galaxy_image_13813_512.png -> galaxy_image_13813.fit (维度：(512, 512))
# 成功转换: galaxy_image_13814_512.png -> galaxy_image_13814.fit (维度：(512, 512))
# 成功转换: galaxy_image_13823_512.png -> galaxy_image_13823.fit (维度：(512, 512))
# 成功转换: galaxy_image_13824_512.png -> galaxy_image_13824.fit (维度：(512, 512))
# 成功转换: galaxy_image_13835_512.png -> galaxy_image_13835.fit (维度：(512, 512))
# 成功转换: galaxy_image_13844_512.png -> galaxy_image_13844.fit (维度：(512, 512))
# 成功转换: galaxy_image_13846_512.png -> galaxy_image_13846.fit (维度：(512, 512))
# 成功转换: galaxy_image_13851_512.png -> galaxy_image_13851.fit (维度：(512, 512))
# 成功转换: galaxy_image_13856_512.png -> galaxy_image_13856.fit (维度：(512, 512))
# 成功转换: galaxy_image_13866_512.png -> galaxy_image_13866.fit (维度：(512, 512))
# 成功转换: galaxy_image_13881_512.png -> galaxy_image_13881.fit (维度：(512, 512))
# 成功转换: galaxy_image_13883_512.png -> galaxy_image_13883.fit (维度：(512, 512))
# 成功转换: galaxy_image_13888_512.png -> galaxy_image_13888.fit (维度：(512, 512))
# 成功转换: galaxy_image_13889_512.png -> galaxy_image_13889.fit (维度：(512, 512))
# 成功转换: galaxy_image_13898_512.png -> galaxy_image_13898.fit (维度：(512, 512))
# 成功转换: galaxy_image_138_512.png -> galaxy_image_138.fit (维度：(512, 512))
# 成功转换: galaxy_image_13902_512.png -> galaxy_image_13902.fit (维度：(512, 512))
# 成功转换: galaxy_image_13911_512.png -> galaxy_image_13911.fit (维度：(512, 512))
# 成功转换: galaxy_image_13920_512.png -> galaxy_image_13920.fit (维度：(512, 512))
# 成功转换: galaxy_image_13921_512.png -> galaxy_image_13921.fit (维度：(512, 512))
# 成功转换: galaxy_image_13925_512.png -> galaxy_image_13925.fit (维度：(512, 512))
# 成功转换: galaxy_image_13931_512.png -> galaxy_image_13931.fit (维度：(512, 512))
# 成功转换: galaxy_image_13939_512.png -> galaxy_image_13939.fit (维度：(512, 512))
# 成功转换: galaxy_image_13942_512.png -> galaxy_image_13942.fit (维度：(512, 512))
# 成功转换: galaxy_image_13947_512.png -> galaxy_image_13947.fit (维度：(512, 512))
# 成功转换: galaxy_image_13948_512.png -> galaxy_image_13948.fit (维度：(512, 512))
# 成功转换: galaxy_image_13954_512.png -> galaxy_image_13954.fit (维度：(512, 512))
# 成功转换: galaxy_image_13955_512.png -> galaxy_image_13955.fit (维度：(512, 512))
# 成功转换: galaxy_image_13964_512.png -> galaxy_image_13964.fit (维度：(512, 512))
# 成功转换: galaxy_image_13968_512.png -> galaxy_image_13968.fit (维度：(512, 512))
# 成功转换: galaxy_image_1396_512.png -> galaxy_image_1396.fit (维度：(512, 512))
# ...
# 成功转换: galaxy_image_8506_512.png -> galaxy_image_8506.fit (维度：(512, 512))
# 成功转换: galaxy_image_8507_512.png -> galaxy_image_8507.fit (维度：(512, 512))
# 成功转换: galaxy_image_8512_512.png -> galaxy_image_8512.fit (维度：(512, 512))
# 成功转换: galaxy_image_8520_512.png -> galaxy_image_8520.fit (维度：(512, 512))
# 成功转换: galaxy_image_8523_512.png -> galaxy_image_8523.fit (维度：(512, 512))
# 成功转换: galaxy_image_8527_512.png -> galaxy_image_8527.fit (维度：(512, 512))
# 成功转换: galaxy_image_8536_512.png -> galaxy_image_8536.fit (维度：(512, 512))
# 成功转换: galaxy_image_853_512.png -> galaxy_image_853.fit (维度：(512, 512))
# 成功转换: galaxy_image_8545_512.png -> galaxy_image_8545.fit (维度：(512, 512))
# 成功转换: galaxy_image_855_512.png -> galaxy_image_855.fit (维度：(512, 512))
# 成功转换: galaxy_image_8572_512.png -> galaxy_image_8572.fit (维度：(512, 512))
# 成功转换: galaxy_image_8576_512.png -> galaxy_image_8576.fit (维度：(512, 512))
# 成功转换: galaxy_image_8577_512.png -> galaxy_image_8577.fit (维度：(512, 512))
# 成功转换: galaxy_image_857_512.png -> galaxy_image_857.fit (维度：(512, 512))
# 成功转换: galaxy_image_8585_512.png -> galaxy_image_8585.fit (维度：(512, 512))
# 成功转换: galaxy_image_8590_512.png -> galaxy_image_8590.fit (维度：(512, 512))
# 成功转换: galaxy_image_8595_512.png -> galaxy_image_8595.fit (维度：(512, 512))
# 成功转换: galaxy_image_8602_512.png -> galaxy_image_8602.fit (维度：(512, 512))
# 成功转换: galaxy_image_8604_512.png -> galaxy_image_8604.fit (维度：(512, 512))
# 成功转换: galaxy_image_8610_512.png -> galaxy_image_8610.fit (维度：(512, 512))
# 成功转换: galaxy_image_8615_512.png -> galaxy_image_8615.fit (维度：(512, 512))
# 成功转换: galaxy_image_8616_512.png -> galaxy_image_8616.fit (维度：(512, 512))
# 成功转换: galaxy_image_8620_512.png -> galaxy_image_8620.fit (维度：(512, 512))
# 成功转换: galaxy_image_8626_512.png -> galaxy_image_8626.fit (维度：(512, 512))
# 成功转换: galaxy_image_8633_512.png -> galaxy_image_8633.fit (维度：(512, 512))
# 成功转换: galaxy_image_8634_512.png -> galaxy_image_8634.fit (维度：(512, 512))
# 成功转换: galaxy_image_8636_512.png -> galaxy_image_8636.fit (维度：(512, 512))
# 成功转换: galaxy_image_8642_512.png -> galaxy_image_8642.fit (维度：(512, 512))
# 成功转换: galaxy_image_8651_512.png -> galaxy_image_8651.fit (维度：(512, 512))
# 成功转换: galaxy_image_8657_512.png -> galaxy_image_8657.fit (维度：(512, 512))
# 成功转换: galaxy_image_8666_512.png -> galaxy_image_8666.fit (维度：(512, 512))
# 成功转换: galaxy_image_8671_512.png -> galaxy_image_8671.fit (维度：(512, 512))
# 成功转换: galaxy_image_8681_512.png -> galaxy_image_8681.fit (维度：(512, 512))
# 成功转换: galaxy_image_8683_512.png -> galaxy_image_8683.fit (维度：(512, 512))
# 成功转换: galaxy_image_8686_512.png -> galaxy_image_8686.fit (维度：(512, 512))
# 成功转换: galaxy_image_8688_512.png -> galaxy_image_8688.fit (维度：(512, 512))
# 成功转换: galaxy_image_8691_512.png -> galaxy_image_8691.fit (维度：(512, 512))
# 成功转换: galaxy_image_8697_512.png -> galaxy_image_8697.fit (维度：(512, 512))
# 成功转换: galaxy_image_8700_512.png -> galaxy_image_8700.fit (维度：(512, 512))
# 成功转换: galaxy_image_8705_512.png -> galaxy_image_8705.fit (维度：(512, 512))
# 成功转换: galaxy_image_8713_512.png -> galaxy_image_8713.fit (维度：(512, 512))
# 成功转换: galaxy_image_8717_512.png -> galaxy_image_8717.fit (维度：(512, 512))
# 成功转换: galaxy_image_8730_512.png -> galaxy_image_8730.fit (维度：(512, 512))
# 成功转换: galaxy_image_873_512.png -> galaxy_image_873.fit (维度：(512, 512))
# 成功转换: galaxy_image_8742_512.png -> galaxy_image_8742.fit (维度：(512, 512))
# 成功转换: galaxy_image_8761_512.png -> galaxy_image_8761.fit (维度：(512, 512))
# 成功转换: galaxy_image_8769_512.png -> galaxy_image_8769.fit (维度：(512, 512))
# 成功转换: galaxy_image_8770_512.png -> galaxy_image_8770.fit (维度：(512, 512))
# 成功转换: galaxy_image_8782_512.png -> galaxy_image_8782.fit (维度：(512, 512))
# 成功转换: galaxy_image_8809_512.png -> galaxy_image_8809.fit (维度：(512, 512))
# 成功转换: galaxy_image_8810_512.png -> galaxy_image_8810.fit (维度：(512, 512))
# 成功转换: galaxy_image_8812_512.png -> galaxy_image_8812.fit (维度：(512, 512))
# 成功转换: galaxy_image_8824_512.png -> galaxy_image_8824.fit (维度：(512, 512))
# 成功转换: galaxy_image_8825_512.png -> galaxy_image_8825.fit (维度：(512, 512))
# 成功转换: galaxy_image_8831_512.png -> galaxy_image_8831.fit (维度：(512, 512))
# 成功转换: galaxy_image_8838_512.png -> galaxy_image_8838.fit (维度：(512, 512))
# 成功转换: galaxy_image_8854_512.png -> galaxy_image_8854.fit (维度：(512, 512))
# 成功转换: galaxy_image_8866_512.png -> galaxy_image_8866.fit (维度：(512, 512))
# 成功转换: galaxy_image_8874_512.png -> galaxy_image_8874.fit (维度：(512, 512))
# 成功转换: galaxy_image_8892_512.png -> galaxy_image_8892.fit (维度：(512, 512))
# 成功转换: galaxy_image_8896_512.png -> galaxy_image_8896.fit (维度：(512, 512))
# 成功转换: galaxy_image_8900_512.png -> galaxy_image_8900.fit (维度：(512, 512))
# 成功转换: galaxy_image_8906_512.png -> galaxy_image_8906.fit (维度：(512, 512))
# 成功转换: galaxy_image_890_512.png -> galaxy_image_890.fit (维度：(512, 512))
# 成功转换: galaxy_image_8920_512.png -> galaxy_image_8920.fit (维度：(512, 512))
# 成功转换: galaxy_image_8927_512.png -> galaxy_image_8927.fit (维度：(512, 512))
# 成功转换: galaxy_image_892_512.png -> galaxy_image_892.fit (维度：(512, 512))
# 成功转换: galaxy_image_8932_512.png -> galaxy_image_8932.fit (维度：(512, 512))
# 成功转换: galaxy_image_8938_512.png -> galaxy_image_8938.fit (维度：(512, 512))
# 成功转换: galaxy_image_8942_512.png -> galaxy_image_8942.fit (维度：(512, 512))
# 成功转换: galaxy_image_8943_512.png -> galaxy_image_8943.fit (维度：(512, 512))
# 成功转换: galaxy_image_8944_512.png -> galaxy_image_8944.fit (维度：(512, 512))
# 成功转换: galaxy_image_8952_512.png -> galaxy_image_8952.fit (维度：(512, 512))
# 成功转换: galaxy_image_8958_512.png -> galaxy_image_8958.fit (维度：(512, 512))
# 成功转换: galaxy_image_8962_512.png -> galaxy_image_8962.fit (维度：(512, 512))
# 成功转换: galaxy_image_8970_512.png -> galaxy_image_8970.fit (维度：(512, 512))
# 成功转换: galaxy_image_8972_512.png -> galaxy_image_8972.fit (维度：(512, 512))
# 成功转换: galaxy_image_8997_512.png -> galaxy_image_8997.fit (维度：(512, 512))
# 成功转换: galaxy_image_9005_512.png -> galaxy_image_9005.fit (维度：(512, 512))
# 成功转换: galaxy_image_9008_512.png -> galaxy_image_9008.fit (维度：(512, 512))
# 成功转换: galaxy_image_9023_512.png -> galaxy_image_9023.fit (维度：(512, 512))
# 成功转换: galaxy_image_9028_512.png -> galaxy_image_9028.fit (维度：(512, 512))
# 成功转换: galaxy_image_9029_512.png -> galaxy_image_9029.fit (维度：(512, 512))
# 成功转换: galaxy_image_9032_512.png -> galaxy_image_9032.fit (维度：(512, 512))
# 成功转换: galaxy_image_9042_512.png -> galaxy_image_9042.fit (维度：(512, 512))
# 成功转换: galaxy_image_9044_512.png -> galaxy_image_9044.fit (维度：(512, 512))
# 成功转换: galaxy_image_9057_512.png -> galaxy_image_9057.fit (维度：(512, 512))
# 成功转换: galaxy_image_905_512.png -> galaxy_image_905.fit (维度：(512, 512))
# 成功转换: galaxy_image_9063_512.png -> galaxy_image_9063.fit (维度：(512, 512))
# 成功转换: galaxy_image_9067_512.png -> galaxy_image_9067.fit (维度：(512, 512))
# 成功转换: galaxy_image_9079_512.png -> galaxy_image_9079.fit (维度：(512, 512))
# 成功转换: galaxy_image_9080_512.png -> galaxy_image_9080.fit (维度：(512, 512))
# 成功转换: galaxy_image_9098_512.png -> galaxy_image_9098.fit (维度：(512, 512))
# 成功转换: galaxy_image_9118_512.png -> galaxy_image_9118.fit (维度：(512, 512))
# 成功转换: galaxy_image_9128_512.png -> galaxy_image_9128.fit (维度：(512, 512))
# 成功转换: galaxy_image_913_512.png -> galaxy_image_913.fit (维度：(512, 512))
# 成功转换: galaxy_image_9142_512.png -> galaxy_image_9142.fit (维度：(512, 512))
# 成功转换: galaxy_image_9144_512.png -> galaxy_image_9144.fit (维度：(512, 512))
# 成功转换: galaxy_image_9153_512.png -> galaxy_image_9153.fit (维度：(512, 512))
# 成功转换: galaxy_image_9156_512.png -> galaxy_image_9156.fit (维度：(512, 512))
# 成功转换: galaxy_image_9180_512.png -> galaxy_image_9180.fit (维度：(512, 512))
# 成功转换: galaxy_image_9188_512.png -> galaxy_image_9188.fit (维度：(512, 512))
# 成功转换: galaxy_image_9196_512.png -> galaxy_image_9196.fit (维度：(512, 512))
# 成功转换: galaxy_image_9198_512.png -> galaxy_image_9198.fit (维度：(512, 512))
# 成功转换: galaxy_image_9200_512.png -> galaxy_image_9200.fit (维度：(512, 512))
# 成功转换: galaxy_image_9211_512.png -> galaxy_image_9211.fit (维度：(512, 512))
# 成功转换: galaxy_image_9214_512.png -> galaxy_image_9214.fit (维度：(512, 512))
# 成功转换: galaxy_image_922_512.png -> galaxy_image_922.fit (维度：(512, 512))
# 成功转换: galaxy_image_9231_512.png -> galaxy_image_9231.fit (维度：(512, 512))
# 成功转换: galaxy_image_9241_512.png -> galaxy_image_9241.fit (维度：(512, 512))
# 成功转换: galaxy_image_9257_512.png -> galaxy_image_9257.fit (维度：(512, 512))
# 成功转换: galaxy_image_9258_512.png -> galaxy_image_9258.fit (维度：(512, 512))
# 成功转换: galaxy_image_9259_512.png -> galaxy_image_9259.fit (维度：(512, 512))
# 成功转换: galaxy_image_9266_512.png -> galaxy_image_9266.fit (维度：(512, 512))
# 成功转换: galaxy_image_9267_512.png -> galaxy_image_9267.fit (维度：(512, 512))
# 成功转换: galaxy_image_9268_512.png -> galaxy_image_9268.fit (维度：(512, 512))
# 成功转换: galaxy_image_9270_512.png -> galaxy_image_9270.fit (维度：(512, 512))
# 成功转换: galaxy_image_9279_512.png -> galaxy_image_9279.fit (维度：(512, 512))
# 成功转换: galaxy_image_927_512.png -> galaxy_image_927.fit (维度：(512, 512))
# 成功转换: galaxy_image_9284_512.png -> galaxy_image_9284.fit (维度：(512, 512))
# 成功转换: galaxy_image_928_512.png -> galaxy_image_928.fit (维度：(512, 512))
# 成功转换: galaxy_image_9294_512.png -> galaxy_image_9294.fit (维度：(512, 512))
# 成功转换: galaxy_image_9296_512.png -> galaxy_image_9296.fit (维度：(512, 512))
# 成功转换: galaxy_image_9297_512.png -> galaxy_image_9297.fit (维度：(512, 512))
# 成功转换: galaxy_image_9300_512.png -> galaxy_image_9300.fit (维度：(512, 512))
# 成功转换: galaxy_image_9308_512.png -> galaxy_image_9308.fit (维度：(512, 512))
# 成功转换: galaxy_image_9309_512.png -> galaxy_image_9309.fit (维度：(512, 512))
# 成功转换: galaxy_image_9310_512.png -> galaxy_image_9310.fit (维度：(512, 512))
# 成功转换: galaxy_image_9324_512.png -> galaxy_image_9324.fit (维度：(512, 512))
# 成功转换: galaxy_image_9331_512.png -> galaxy_image_9331.fit (维度：(512, 512))
# 成功转换: galaxy_image_934_512.png -> galaxy_image_934.fit (维度：(512, 512))
# 成功转换: galaxy_image_9356_512.png -> galaxy_image_9356.fit (维度：(512, 512))
# 成功转换: galaxy_image_9364_512.png -> galaxy_image_9364.fit (维度：(512, 512))
# 成功转换: galaxy_image_9367_512.png -> galaxy_image_9367.fit (维度：(512, 512))
# 成功转换: galaxy_image_9374_512.png -> galaxy_image_9374.fit (维度：(512, 512))
# 成功转换: galaxy_image_937_512.png -> galaxy_image_937.fit (维度：(512, 512))
# 成功转换: galaxy_image_9381_512.png -> galaxy_image_9381.fit (维度：(512, 512))
# 成功转换: galaxy_image_9388_512.png -> galaxy_image_9388.fit (维度：(512, 512))
# 成功转换: galaxy_image_938_512.png -> galaxy_image_938.fit (维度：(512, 512))
# 成功转换: galaxy_image_9396_512.png -> galaxy_image_9396.fit (维度：(512, 512))
# 成功转换: galaxy_image_9425_512.png -> galaxy_image_9425.fit (维度：(512, 512))
# 成功转换: galaxy_image_9429_512.png -> galaxy_image_9429.fit (维度：(512, 512))
# 成功转换: galaxy_image_9437_512.png -> galaxy_image_9437.fit (维度：(512, 512))
# 成功转换: galaxy_image_9438_512.png -> galaxy_image_9438.fit (维度：(512, 512))
# 成功转换: galaxy_image_9444_512.png -> galaxy_image_9444.fit (维度：(512, 512))
# 成功转换: galaxy_image_9468_512.png -> galaxy_image_9468.fit (维度：(512, 512))
# 成功转换: galaxy_image_9492_512.png -> galaxy_image_9492.fit (维度：(512, 512))
# 成功转换: galaxy_image_9497_512.png -> galaxy_image_9497.fit (维度：(512, 512))
# 成功转换: galaxy_image_9499_512.png -> galaxy_image_9499.fit (维度：(512, 512))
# 成功转换: galaxy_image_94_512.png -> galaxy_image_94.fit (维度：(512, 512))
# 成功转换: galaxy_image_9501_512.png -> galaxy_image_9501.fit (维度：(512, 512))
# 成功转换: galaxy_image_9507_512.png -> galaxy_image_9507.fit (维度：(512, 512))
# 成功转换: galaxy_image_9515_512.png -> galaxy_image_9515.fit (维度：(512, 512))
# 成功转换: galaxy_image_9516_512.png -> galaxy_image_9516.fit (维度：(512, 512))
# 成功转换: galaxy_image_9556_512.png -> galaxy_image_9556.fit (维度：(512, 512))
# 成功转换: galaxy_image_9563_512.png -> galaxy_image_9563.fit (维度：(512, 512))
# 成功转换: galaxy_image_9566_512.png -> galaxy_image_9566.fit (维度：(512, 512))
# 成功转换: galaxy_image_9580_512.png -> galaxy_image_9580.fit (维度：(512, 512))
# 成功转换: galaxy_image_9582_512.png -> galaxy_image_9582.fit (维度：(512, 512))
# 成功转换: galaxy_image_9585_512.png -> galaxy_image_9585.fit (维度：(512, 512))
# 成功转换: galaxy_image_9586_512.png -> galaxy_image_9586.fit (维度：(512, 512))
# 成功转换: galaxy_image_9589_512.png -> galaxy_image_9589.fit (维度：(512, 512))
# 成功转换: galaxy_image_9591_512.png -> galaxy_image_9591.fit (维度：(512, 512))
# 成功转换: galaxy_image_9601_512.png -> galaxy_image_9601.fit (维度：(512, 512))
# 成功转换: galaxy_image_9609_512.png -> galaxy_image_9609.fit (维度：(512, 512))
# 成功转换: galaxy_image_9610_512.png -> galaxy_image_9610.fit (维度：(512, 512))
# 成功转换: galaxy_image_9619_512.png -> galaxy_image_9619.fit (维度：(512, 512))
# 成功转换: galaxy_image_9621_512.png -> galaxy_image_9621.fit (维度：(512, 512))
# 成功转换: galaxy_image_9658_512.png -> galaxy_image_9658.fit (维度：(512, 512))
# 成功转换: galaxy_image_965_512.png -> galaxy_image_965.fit (维度：(512, 512))
# 成功转换: galaxy_image_9664_512.png -> galaxy_image_9664.fit (维度：(512, 512))
# 成功转换: galaxy_image_9681_512.png -> galaxy_image_9681.fit (维度：(512, 512))
# 成功转换: galaxy_image_9694_512.png -> galaxy_image_9694.fit (维度：(512, 512))
# 成功转换: galaxy_image_9695_512.png -> galaxy_image_9695.fit (维度：(512, 512))
# 成功转换: galaxy_image_96_512.png -> galaxy_image_96.fit (维度：(512, 512))
# 成功转换: galaxy_image_9716_512.png -> galaxy_image_9716.fit (维度：(512, 512))
# 成功转换: galaxy_image_9718_512.png -> galaxy_image_9718.fit (维度：(512, 512))
# 成功转换: galaxy_image_9720_512.png -> galaxy_image_9720.fit (维度：(512, 512))
# 成功转换: galaxy_image_9722_512.png -> galaxy_image_9722.fit (维度：(512, 512))
# 成功转换: galaxy_image_9735_512.png -> galaxy_image_9735.fit (维度：(512, 512))
# 成功转换: galaxy_image_9737_512.png -> galaxy_image_9737.fit (维度：(512, 512))
# 成功转换: galaxy_image_9746_512.png -> galaxy_image_9746.fit (维度：(512, 512))
# 成功转换: galaxy_image_9748_512.png -> galaxy_image_9748.fit (维度：(512, 512))
# 成功转换: galaxy_image_9769_512.png -> galaxy_image_9769.fit (维度：(512, 512))
# 成功转换: galaxy_image_977_512.png -> galaxy_image_977.fit (维度：(512, 512))
# 成功转换: galaxy_image_9785_512.png -> galaxy_image_9785.fit (维度：(512, 512))
# 成功转换: galaxy_image_9795_512.png -> galaxy_image_9795.fit (维度：(512, 512))
# 成功转换: galaxy_image_9796_512.png -> galaxy_image_9796.fit (维度：(512, 512))
# 成功转换: galaxy_image_9804_512.png -> galaxy_image_9804.fit (维度：(512, 512))
# 成功转换: galaxy_image_9820_512.png -> galaxy_image_9820.fit (维度：(512, 512))
# 成功转换: galaxy_image_9821_512.png -> galaxy_image_9821.fit (维度：(512, 512))
# 成功转换: galaxy_image_9825_512.png -> galaxy_image_9825.fit (维度：(512, 512))
# 成功转换: galaxy_image_9826_512.png -> galaxy_image_9826.fit (维度：(512, 512))
# 成功转换: galaxy_image_9830_512.png -> galaxy_image_9830.fit (维度：(512, 512))
# 成功转换: galaxy_image_9835_512.png -> galaxy_image_9835.fit (维度：(512, 512))
# 成功转换: galaxy_image_9847_512.png -> galaxy_image_9847.fit (维度：(512, 512))
# 成功转换: galaxy_image_9848_512.png -> galaxy_image_9848.fit (维度：(512, 512))
# 成功转换: galaxy_image_9856_512.png -> galaxy_image_9856.fit (维度：(512, 512))
# 成功转换: galaxy_image_9857_512.png -> galaxy_image_9857.fit (维度：(512, 512))
# 成功转换: galaxy_image_9890_512.png -> galaxy_image_9890.fit (维度：(512, 512))
# 成功转换: galaxy_image_9904_512.png -> galaxy_image_9904.fit (维度：(512, 512))
# 成功转换: galaxy_image_9909_512.png -> galaxy_image_9909.fit (维度：(512, 512))
# 成功转换: galaxy_image_990_512.png -> galaxy_image_990.fit (维度：(512, 512))
# 成功转换: galaxy_image_9917_512.png -> galaxy_image_9917.fit (维度：(512, 512))
# 成功转换: galaxy_image_9920_512.png -> galaxy_image_9920.fit (维度：(512, 512))
# 成功转换: galaxy_image_9922_512.png -> galaxy_image_9922.fit (维度：(512, 512))
# 成功转换: galaxy_image_9929_512.png -> galaxy_image_9929.fit (维度：(512, 512))
# 成功转换: galaxy_image_9932_512.png -> galaxy_image_9932.fit (维度：(512, 512))
# 成功转换: galaxy_image_995_512.png -> galaxy_image_995.fit (维度：(512, 512))
# 成功转换: galaxy_image_9968_512.png -> galaxy_image_9968.fit (维度：(512, 512))
# 成功转换: galaxy_image_996_512.png -> galaxy_image_996.fit (维度：(512, 512))
# 成功转换: galaxy_image_9970_512.png -> galaxy_image_9970.fit (维度：(512, 512))
# 成功转换: galaxy_image_9972_512.png -> galaxy_image_9972.fit (维度：(512, 512))
# 成功转换: galaxy_image_9973_512.png -> galaxy_image_9973.fit (维度：(512, 512))
# 成功转换: galaxy_image_9978_512.png -> galaxy_image_9978.fit (维度：(512, 512))
# 成功转换: galaxy_image_9984_512.png -> galaxy_image_9984.fit (维度：(512, 512))
# 成功转换: galaxy_image_9985_512.png -> galaxy_image_9985.fit (维度：(512, 512))
# 成功转换: galaxy_image_9989_512.png -> galaxy_image_9989.fit (维度：(512, 512))
# 成功转换: galaxy_image_999_512.png -> galaxy_image_999.fit (维度：(512, 512))

# %% [markdown]
# ### ori.fit->moxing.png

# %%
def fits_to_png_512(input_dir, output_dir, target_size=(512, 512)):
    """
    将指定目录下的FITS文件批量转换为512x512的PNG图像

    参数：
    - input_dir: 输入目录路径（包含.fit文件）
    - output_dir: 输出目录路径（保存.png文件）
    - target_size: 目标图像尺寸，默认512x512
    """
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)

    # 获取待处理文件列表
    file_list = [f for f in os.listdir(input_dir) if f.endswith('.fit')]

    # 使用tqdm创建进度条[6,8](@ref)
    with tqdm(total=len(file_list), desc="转换进度", unit="文件") as pbar:
        for filename in file_list:
            try:
                # 读取FITS文件[9,10](@ref)
                with fits.open(os.path.join(input_dir, filename)) as hdul:
                    data = hdul[0].data.astype(np.float32)

                    # 数据维度验证与处理
                    if len(data.shape) == 3:  # 处理三维数据（如RGB）
                        data = data.mean(axis=0)  # 取平均或选择特定通道
                    elif len(data.shape) != 2:
                        raise ValueError(f"非常规数据维度：{data.shape}")

                    # 数据归一化处理
                    data_normalized = (data - np.min(data)) / (np.max(data) - np.min(data)) * 255

                    # 创建图像对象并调整尺寸[1](@ref)
                    img = Image.fromarray(data_normalized.astype(np.uint8))
                    img_resized = img.resize(target_size, Image.LANCZOS)

                    # 保存PNG文件
                    output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}.png")
                    img_resized.save(output_path)

                    # 更新进度描述[7](@ref)
                    pbar.set_postfix({"状态": "成功", "当前文件": filename[:15]+"..."})

            except Exception as e:
                pbar.set_postfix({"状态": f"失败: {str(e)}", "当前文件": filename[:15]+"..."})
            finally:
                pbar.update(1)

# 示例调用
if __name__ == "__main__":
    input_dir = "data_ori_fit"   # FITS文件目录
    output_dir = "data_moxing_png"  # 输出目录

    fits_to_png_512(input_dir, output_dir)
# Out:
# 转换进度: 100%|██████████| 2500/2500 [01:23<00:00, 30.01文件/s, 状态=成功, 当前文件=galaxy_image_99...]

# %% [markdown]
# ### 带宽涂污（ori.fit->dirty.fit）

# %%
# 相对路径：输入、输出目录
input_dir  = 'data_ori_fit'
output_dir = 'data_dirty_fit'
os.makedirs(output_dir, exist_ok=True)

# 模拟参数设置
frac_bandwidth = 0.2   # 宽带相对带宽 (例如20%)
num_channels = 5       # 模拟的频率通道数（在带宽内采样的频率点）
# UV覆盖相关参数
max_baseline_fraction = 0.5  # 最大基线长度相对于UV平面最大频率的比例 (决定分辨率, 0.5表示UV半径50%)
num_baselines = 2000         # 随机选择的基线数量（采样点数量，越少则UV覆盖越稀疏）

# 遍历输入目录下所有FITS图像文件
for file_path in glob.glob(os.path.join(input_dir, "*.fit*")):
    # 读取FITS图像数据
    hdul = fits.open(file_path)
    data = hdul[0].data.astype(np.float64)  # 使用float64提高FFT精度
    header = hdul[0].header
    hdul.close()
    # 如果图像有多于2维（例如包含多通道），压缩成2D图像
    if data.ndim > 2:
        data = data.squeeze()
    Ny, Nx = data.shape  # 图像的高度和宽度

    # 1. 对原始模型图像进行二维傅里叶变换，获取"真值"天空的频谱（能见度）数据
    #   - 先将图像进行 fftshift 使得图像中心对应相位中心，然后执行 FFT，再 fftshift 得到零频率在中心的频谱
    ft_image = np.fft.fftshift(np.fft.fft2(np.fft.ifftshift(data)))
    # 此时 ft_image 为复数数组，代表 UV 平面的理想完全采样情况

    # 2. 生成 UV 采样掩膜，模拟稀疏阵列的不完整 UV 覆盖
    uv_mask = np.zeros_like(ft_image, dtype=bool)
    u0 = Nx // 2  # UV平面中心 u 坐标
    v0 = Ny // 2  # UV平面中心 v 坐标
    max_r = min(u0, v0) * max_baseline_fraction  # 最大采样半径
    np.random.seed(42)  # 固定随机种子，确保每次运行采样一致（可根据需要移除以获得不同随机采样）

    # 随机生成基线点在 UV 平面的坐标偏移 (du, dv)，在圆形区域内均匀分布
    points = []
    count = 0
    while count < num_baselines:
        u_rand = (np.random.rand() * 2 - 1) * max_r
        v_rand = (np.random.rand() * 2 - 1) * max_r
        if u_rand**2 + v_rand**2 <= max_r**2:
            u_idx = int(np.round(u_rand))
            v_idx = int(np.round(v_rand))
            if abs(u_idx) <= u0 and abs(v_idx) <= v0:
                points.append((u_idx, v_idx))
                count += 1
    # 去除重复点和零点
    unique_points = set(points)
    if (0,0) in unique_points:
        unique_points.remove((0,0))
    # 对于每个选取的基线点，标记其正负对称点（保证共轭对称，以产生实值图像）
    for (du, dv) in list(unique_points):
        u_pos = u0 + du;  v_pos = v0 + dv
        u_neg = u0 - du;  v_neg = v0 - dv
        uv_mask[int(v_pos), int(u_pos)] = True
        uv_mask[int(v_neg), int(u_neg)] = True

    # 3. 模拟宽带频率涂污效应（bandwidth smearing）
    #    对于每条基线，在多个频率采样下获取能见度并取平均，模拟带宽内信号的相干平均
    observed_vis = np.zeros_like(ft_image, dtype=np.complex128)  # 存储观测到的(平均后)能见度
    f0 = 1.0  # 参考频率（归一化）
    freqs = f0 * (1 + np.linspace(-frac_bandwidth/2, frac_bandwidth/2, num_channels))  # 频率通道列表

    processed = set()
    for (du, dv) in unique_points:
        # 确保每对共轭基线只处理一次
        if (du, dv) in processed or (-du, -dv) in processed:
            continue
        processed.add((du, dv)); processed.add((-du, -dv))
        # 基线在 UV 平面上的基准坐标（以中心为0点偏移 du,dv）
        u_base = u0 + du;    v_base = v0 + dv
        u_base_neg = u0 - du; v_base_neg = v0 - dv
        if not (0 <= u_base < Nx and 0 <= v_base < Ny):
            continue
        # 收集该基线在各个频率的能见度值
        vis_vals = []
        vis_vals_neg = []
        for f in freqs:
            scale = f / f0  # 频率相对于 f0 的比例
            # 计算该频率下对应的 UV 坐标 (相同物理基线按频率缩放 UV距离)
            u_scaled = u0 + du * scale
            v_scaled = v0 + dv * scale
            u_scaled_neg = u0 - du * scale
            v_scaled_neg = v0 - dv * scale
            # 取与该坐标最接近的网格点的能见度值 (近似插值)
            u_idx = int(np.round(u_scaled)); v_idx = int(np.round(v_scaled))
            u_idx_neg = int(np.round(u_scaled_neg)); v_idx_neg = int(np.round(v_scaled_neg))
            if 0 <= u_idx < Nx and 0 <= v_idx < Ny:
                vis_vals.append(ft_image[v_idx, u_idx])
            else:
                vis_vals.append(0+0j)
            if 0 <= u_idx_neg < Nx and 0 <= v_idx_neg < Ny:
                vis_vals_neg.append(ft_image[v_idx_neg, u_idx_neg])
            else:
                vis_vals_neg.append(0+0j)
        # 频率平均能见度（复数平均）
        vis_avg = sum(vis_vals) / len(vis_vals) if len(vis_vals) > 0 else 0+0j
        vis_avg_neg = sum(vis_vals_neg) / len(vis_vals_neg) if len(vis_vals_neg) > 0 else 0+0j
        # 将平均后的能见度赋值回观测能见度矩阵
        observed_vis[int(v_base), int(u_base)] = vis_avg
        observed_vis[int(v_base_neg), int(u_base_neg)] = vis_avg_neg

    # 4. 逆傅里叶变换得到脏图
    #    - 未采样的位置在 observed_vis 中为0，导致合成波束(PSF)产生旁瓣
    dirty_image_complex = np.fft.ifft2(np.fft.ifftshift(observed_vis))
    dirty_image = np.real(np.fft.fftshift(dirty_image_complex))  # 取实部作为脏图强度分布

    # 5. 将生成的脏图写入FITS文件保存
    out_name = os.path.basename(file_path)
    out_path = os.path.join(output_dir, out_name)
    # 复制原始头信息，并添加历史记录说明
    header_dirty = header.copy()
    header_dirty.add_history("Simulated dirty map (sparse uv sampling + bandwidth smearing)")
    fits.writeto(out_path, dirty_image.astype(np.float32), header_dirty, overwrite=True)

    # （可选）可使用 matplotlib 在此处显示或保存图像以检查效果

print("Dirty map simulation completed.")
# Out:
# Dirty map simulation completed.

# %% [markdown]
# ### dirty.fit->dirty.png

# %%
def fits_to_png_512(input_dir, output_dir, target_size=(512, 512)):
    """
    将指定目录下的FITS文件批量转换为512x512的PNG图像

    参数：
    - input_dir: 输入目录路径（包含.fit文件）
    - output_dir: 输出目录路径（保存.png文件）
    - target_size: 目标图像尺寸，默认512x512
    """
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)

    # 获取待处理文件列表
    file_list = [f for f in os.listdir(input_dir) if f.endswith('.fit')]

    # 使用tqdm创建进度条[6,8](@ref)
    with tqdm(total=len(file_list), desc="转换进度", unit="文件") as pbar:
        for filename in file_list:
            try:
                # 读取FITS文件[9,10](@ref)
                with fits.open(os.path.join(input_dir, filename)) as hdul:
                    data = hdul[0].data.astype(np.float32)

                    # 数据维度验证与处理
                    if len(data.shape) == 3:  # 处理三维数据（如RGB）
                        data = data.mean(axis=0)  # 取平均或选择特定通道
                    elif len(data.shape) != 2:
                        raise ValueError(f"非常规数据维度：{data.shape}")

                    # 数据归一化处理
                    data_normalized = (data - np.min(data)) / (np.max(data) - np.min(data)) * 255

                    # 创建图像对象并调整尺寸[1](@ref)
                    img = Image.fromarray(data_normalized.astype(np.uint8))
                    img_resized = img.resize(target_size, Image.LANCZOS)

                    # 保存PNG文件
                    output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_dirty.png")
                    img_resized.save(output_path)

                    # 更新进度描述[7](@ref)
                    pbar.set_postfix({"状态": "成功", "当前文件": filename[:15]+"..."})

            except Exception as e:
                pbar.set_postfix({"状态": f"失败: {str(e)}", "当前文件": filename[:15]+"..."})
            finally:
                pbar.update(1)

# 示例调用
if __name__ == "__main__":
    input_dir = "data_dirty_fit"   # FITS文件目录
    output_dir = "data_dirty_png"  # 输出目录

    fits_to_png_512(input_dir, output_dir)
# Out:
# 转换进度: 100%|██████████| 2500/2500 [01:51<00:00, 22.43文件/s, 状态=成功, 当前文件=galaxy_image_99...]
